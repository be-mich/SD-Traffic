# %%
#import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#read in data
traffic_collisions_details=pd.read_csv("https://seshat.datasd.org/pd/pd_collisions_details_datasd.csv")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (0,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
#read in dictionary

traffic_collisions_dictionary = pd.read_csv("https://seshat.datasd.org/pd/pd_collisions_details_dictionary_datasd.csv")

# %%
person_veh_dictionary = pd.read_csv("https://seshat.datasd.org/pd/person_veh_type_dictionary_datasd.csv")

# %%
traffic_collisions_details.head()
# Out:
#   report_id            date_time              person_role person_injury_lvl  \
# 0    600096  2015-01-01 15:19:00                   DRIVER               NaN
# 1    600096  2015-01-01 15:19:00  PARKED VEHICLE OCCUPANT               NaN
# 2    600068  2015-01-02 13:04:00                   DRIVER           VISABLE
# 3    600051  2015-01-02 20:15:00  PARKED VEHICLE OCCUPANT               NaN
# 4    600441  2015-01-13 13:59:00                BICYCLIST              PAIN
#
#   person_veh_type    veh_type  veh_make             veh_model police_beat  \
# 0             NaN         NaN      FORD                   NaN         112
# 1             NaN         NaN      FORD               MUSTANG         112
# 2             NaN  MOTORCYCLE  KAWASAKI                   NaN         437
# 3             NaN         NaN    TOYOTA  MATRIX (SPORT WAGON)         833
# 4             NaN     BICYCLE       NaN                   NaN         611
#
#    address_no_primary  ... address_sfx_primary address_pd_intersecting  \
# 0                3600  ...           BOULEVARD
# 1                3600  ...           BOULEVARD
# 2                2800  ...              STREET
# 3                3800  ...              AVENUE
# 4                3500  ...               DRIVE
#
#   address_name_intersecting address_sfx_intersecting violation_section  \
# 0                                                                22107
# 1                                                                22107
# 2                                                               21801A
# 3                                                                22107
# 4                                                                82.22
#
#   violation_type                                     charge_desc injured  \
# 0             VC          TURNING MOVEMENTS AND REQUIRED SIGNALS       0
# 1             VC          TURNING MOVEMENTS AND REQUIRED SIGNALS       0
# 2             VC            LEFT TURN YIELD UNTIL SAFE OR U-TURN       1
# 3             VC          TURNING MOVEMENTS AND REQUIRED SIGNALS       0
# 4             MC  STOP UPON EMERGING FROM ALLEY/PRIVATE DRIVEWAY       1
#
#   killed  hit_run_lvl
# 0      0          NaN
# 1      0          NaN
# 2      0  MISDEMEANOR
# 3      0  MISDEMEANOR
# 4      0          NaN
#
# [5 rows x 22 columns]

# %%
traffic_collisions_dictionary.head()
# Out:
#                field                                        description  \
# 0          report_id                            Collision report number
# 1          date_time                             Date/time of collision
# 2        person_role      Description of person's role in the collision
# 3  person_injury_lvl            Description of person's level of injury
# 4    person_veh_type  Description of type of vehicle (categories def...
#
#                                      possible_values
# 0                                                NaN
# 1                                                NaN
# 2  BICYCLIST, DRIVER, OTHER, PARKED VEHICLE OCCUP...
# 3                 FATAL, NULL, PAIN, SEVERE, VISABLE
# 4  see list linked at https://data.sandiego.gov/d...

# %%
person_veh_dictionary.head()
# Out:
#                       possible_values
# 0  Passenger Car, Station Wagon, Jeep
# 1                          Motorcycle
# 2          Motor Driven Cycle/Scooter
# 3                             Bicycle
# 4                   Motorized Bicycle

# %% [markdown]
# Lets see what values are present in select columns

# %%
#types of person_role
print(traffic_collisions_details['person_role'].value_counts())
# Out:
# DRIVER                     77304
# PARKED VEHICLE OCCUPANT    26891
# PASSENGER                   8122
# BICYCLIST                   2108
# OTHER                        289
# Name: person_role, dtype: int64

# %%
#types of violation section 
print(traffic_collisions_details['violation_section'].value_counts())
# Out:
# 22107        28949
# MISC-HAZ     18678
# 22350        16104
# 21453A        8032
# 22106         7099
#              ...
# GANGS            1
# 23110A           1
# 29003B           1
# 21235(I)         1
# 63.0102B1        1
# Name: violation_section, Length: 299, dtype: int64

# %%
#location of collision 

print(traffic_collisions_details['address_road_primary'].value_counts())
# Out:
# EL CAJON           2887
# UNIVERSITY         2861
# IMPERIAL           1542
# BALBOA             1519
# CLAIREMONT MESA    1517
#                    ...
# CAMTO LA BAR          1
# OLITE                 1
# DEL MAR MEZA          1
# FLOWER MEADOW         1
# BLOCK KETTNER         1
# Name: address_road_primary, Length: 4989, dtype: int64

# %%
#dates
print(traffic_collisions_details['date_time'].value_counts())
# Out:
# 2018-09-14 15:55:00    16
# 2019-03-13 14:55:00    15
# 2021-07-09 23:20:00    15
# 2020-06-21 18:20:05    14
# 2021-04-09 22:25:38    13
#                        ..
# 2017-06-16 06:43:00     1
# 2019-11-21 16:30:00     1
# 2018-12-16 13:00:00     1
# 2018-03-27 12:05:00     1
# 2015-10-01 17:25:00     1
# Name: date_time, Length: 65056, dtype: int64

# %%
#date range
print(traffic_collisions_details['date_time'].min())
print(traffic_collisions_details['date_time'].max())
# Out:
# 2015-01-01 15:19:00
# 2022-05-10 01:40:00

# %%
#violation section types
print(traffic_collisions_details['violation_type'].value_counts())
# Out:
# VC    118326
# MC        45
# ZZ        20
# CO        11
# PC         9
# HS         3
# HN         2
# Name: violation_type, dtype: int64

# %%
#police beat
print(traffic_collisions_details['police_beat'].value_counts())
# Out:
# 122    4547
# 242    2611
# 813    2553
# 313    2375
# 521    2171
#        ...
# 601       1
# 0SD       1
# 404       1
# 419       1
# 600       1
# Name: police_beat, Length: 284, dtype: int64

# %%
#hit_run column
print(traffic_collisions_details['hit_run_lvl'].value_counts())
# Out:
# MISDEMEANOR    46932
# FELONY           752
# Name: hit_run_lvl, dtype: int64

# %%
#charge description--violation section description for primary collision factor
print(traffic_collisions_details['charge_desc'].value_counts())
# Out:
# MISCELLANEOUS HAZARDOUS VIOLATIONS OF THE VEHICLE CODE       18674
# TURNING MOVEMENTS AND REQUIRED SIGNALS                       17182
# TURNS:UNSAFE TURN AND/OR NO TURN SIGNAL (I)                  11751
# VIOLATION OF BASIC SPEED LAW, SPEED UNSAFE FOR CONDITIONS     8809
# UNSAFE SPEED (BASIC SPEED LAW) (I)                            7289
#                                                              ...
# PEDESTRIAN ON FREEWAY (I)                                        1
# DISOBEY TRAFFIC CONTROL CONSTRUCTION SITE                        1
# VEHICLE OBSTRUCTING CROSSWALK/STREET                             1
# MINOR UNDER 21YR DRIVE W/BAC 0.05 (I)                            1
# PEDESTRIAN ON FREEWAY                                            1
# Name: charge_desc, Length: 435, dtype: int64

# %%
#look at describe?
traffic_collisions_details.describe()
    #not helpful because three columns are numeric type
# Out:
#        address_no_primary        injured         killed
# count        1.184160e+05  118416.000000  118416.000000
# mean         4.887950e+03       0.731151       0.005700
# std          8.739020e+04       1.179692       0.083779
# min          0.000000e+00       0.000000       0.000000
# 25%          1.400000e+03       0.000000       0.000000
# 50%          3.600000e+03       1.000000       0.000000
# 75%          5.400000e+03       1.000000       0.000000
# max          1.228202e+07     180.000000       4.000000

# %%
traffic_collisions_details.shape[1]
# Out:
# 22

# %% [markdown]
# Lets clean up these data

# %%
#get datatype for each column
traffic_collisions_details.dtypes
# Out:
# report_id                    object
# date_time                    object
# person_role                  object
# person_injury_lvl            object
# person_veh_type              object
# veh_type                     object
# veh_make                     object
# veh_model                    object
# police_beat                  object
# address_no_primary            int64
# address_pd_primary           object
# address_road_primary         object
# address_sfx_primary          object
# address_pd_intersecting      object
# address_name_intersecting    object
# address_sfx_intersecting     object
# violation_section            object
# violation_type               object
# charge_desc                  object
# injured                       int64
# killed                        int64
# hit_run_lvl                  object
# dtype: object

# %%
#check for missing data

traffic_collisions_details.head()
# Out:
#   report_id            date_time              person_role person_injury_lvl  \
# 0    600096  2015-01-01 15:19:00                   DRIVER               NaN
# 1    600096  2015-01-01 15:19:00  PARKED VEHICLE OCCUPANT               NaN
# 2    600068  2015-01-02 13:04:00                   DRIVER           VISABLE
# 3    600051  2015-01-02 20:15:00  PARKED VEHICLE OCCUPANT               NaN
# 4    600441  2015-01-13 13:59:00                BICYCLIST              PAIN
#
#   person_veh_type    veh_type  veh_make             veh_model police_beat  \
# 0             NaN         NaN      FORD                   NaN         112
# 1             NaN         NaN      FORD               MUSTANG         112
# 2             NaN  MOTORCYCLE  KAWASAKI                   NaN         437
# 3             NaN         NaN    TOYOTA  MATRIX (SPORT WAGON)         833
# 4             NaN     BICYCLE       NaN                   NaN         611
#
#    address_no_primary  ... address_sfx_primary address_pd_intersecting  \
# 0                3600  ...           BOULEVARD
# 1                3600  ...           BOULEVARD
# 2                2800  ...              STREET
# 3                3800  ...              AVENUE
# 4                3500  ...               DRIVE
#
#   address_name_intersecting address_sfx_intersecting violation_section  \
# 0                                                                22107
# 1                                                                22107
# 2                                                               21801A
# 3                                                                22107
# 4                                                                82.22
#
#   violation_type                                     charge_desc injured  \
# 0             VC          TURNING MOVEMENTS AND REQUIRED SIGNALS       0
# 1             VC          TURNING MOVEMENTS AND REQUIRED SIGNALS       0
# 2             VC            LEFT TURN YIELD UNTIL SAFE OR U-TURN       1
# 3             VC          TURNING MOVEMENTS AND REQUIRED SIGNALS       0
# 4             MC  STOP UPON EMERGING FROM ALLEY/PRIVATE DRIVEWAY       1
#
#   killed  hit_run_lvl
# 0      0          NaN
# 1      0          NaN
# 2      0  MISDEMEANOR
# 3      0  MISDEMEANOR
# 4      0          NaN
#
# [5 rows x 22 columns]

# %%
#check empty columns

print(traffic_collisions_details['address_pd_intersecting'].unique()) #empty strings
print(traffic_collisions_details['address_name_intersecting'].unique())
print(traffic_collisions_details['address_sfx_intersecting'].unique())
# Out:
# [' ' 'W' 'E' 'N' 'S' 'SE']
# [' ' 'I-15 SB' 'UNIVERSITY' ... 'Wahington'
#  'East curbline of 3800 Seventh' 'MONTETUMA']
# [' ' 'AVENUE' 'BOULEVARD' 'STREET' 'DRIVE' 'ROAD' 'WAY' 'DRIVEWAY' 'LANE'
#  'PARKWAY' 'RAMP' 'HIGHWAY' 'PLACE' 'TERRACE' 'COURT' 'ROW' 'POINT' 'WALK'
#  'CIRCLE' 'SQUARE' nan 'FREEWAY' 'TRAIL' 'PLAZA' 'ALLEY' 'BRIDGE'
#  'ST RAMP' 'LOOP' 'MALL']

# %%
#replace empty strings with null values
traffic_collisions_details_edited = traffic_collisions_details.replace(r'^\s+$', np.nan, regex=True)

# %%
traffic_collisions_details_edited.head()
# Out:
#   report_id            date_time              person_role person_injury_lvl  \
# 0    600096  2015-01-01 15:19:00                   DRIVER               NaN
# 1    600096  2015-01-01 15:19:00  PARKED VEHICLE OCCUPANT               NaN
# 2    600068  2015-01-02 13:04:00                   DRIVER           VISABLE
# 3    600051  2015-01-02 20:15:00  PARKED VEHICLE OCCUPANT               NaN
# 4    600441  2015-01-13 13:59:00                BICYCLIST              PAIN
#
#   person_veh_type    veh_type  veh_make             veh_model police_beat  \
# 0             NaN         NaN      FORD                   NaN         112
# 1             NaN         NaN      FORD               MUSTANG         112
# 2             NaN  MOTORCYCLE  KAWASAKI                   NaN         437
# 3             NaN         NaN    TOYOTA  MATRIX (SPORT WAGON)         833
# 4             NaN     BICYCLE       NaN                   NaN         611
#
#    address_no_primary  ... address_sfx_primary address_pd_intersecting  \
# 0                3600  ...           BOULEVARD                     NaN
# 1                3600  ...           BOULEVARD                     NaN
# 2                2800  ...              STREET                     NaN
# 3                3800  ...              AVENUE                     NaN
# 4                3500  ...               DRIVE                     NaN
#
#   address_name_intersecting address_sfx_intersecting violation_section  \
# 0                       NaN                      NaN             22107
# 1                       NaN                      NaN             22107
# 2                       NaN                      NaN            21801A
# 3                       NaN                      NaN             22107
# 4                       NaN                      NaN             82.22
#
#   violation_type                                     charge_desc injured  \
# 0             VC          TURNING MOVEMENTS AND REQUIRED SIGNALS       0
# 1             VC          TURNING MOVEMENTS AND REQUIRED SIGNALS       0
# 2             VC            LEFT TURN YIELD UNTIL SAFE OR U-TURN       1
# 3             VC          TURNING MOVEMENTS AND REQUIRED SIGNALS       0
# 4             MC  STOP UPON EMERGING FROM ALLEY/PRIVATE DRIVEWAY       1
#
#   killed  hit_run_lvl
# 0      0          NaN
# 1      0          NaN
# 2      0  MISDEMEANOR
# 3      0  MISDEMEANOR
# 4      0          NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# Now lets check the report ID. Does the report ID uniquely identify an collision?

# %%
#check if report_id is unique 

print(traffic_collisions_details_edited['report_id'].nunique())
print(len(traffic_collisions_details_edited))
    #repeated report_id, one row per person involved in collision
# Out:
# 67968
# 118416

# %%
#lets see how many involve multiple people

multiple_people = traffic_collisions_details_edited[traffic_collisions_details_edited.duplicated('report_id', keep = False)]
multiple_people
# Out:
#        report_id            date_time              person_role  \
# 0         600096  2015-01-01 15:19:00                   DRIVER
# 1         600096  2015-01-01 15:19:00  PARKED VEHICLE OCCUPANT
# 4         600441  2015-01-13 13:59:00                BICYCLIST
# 5         600441  2015-01-13 13:59:00                   DRIVER
# 8         503789  2015-03-03 10:30:00                   DRIVER
# ...          ...                  ...                      ...
# 114708  22202775  2022-05-09 23:34:00  PARKED VEHICLE OCCUPANT
# 114709  22202775  2022-05-09 23:34:00                   DRIVER
# 114711  22202777  2022-05-10 01:40:00                   DRIVER
# 114712  22202777  2022-05-10 01:40:00                PASSENGER
# 114713  22202777  2022-05-10 01:40:00  PARKED VEHICLE OCCUPANT
#
#        person_injury_lvl                     person_veh_type    veh_type  \
# 0                    NaN                                 NaN         NaN
# 1                    NaN                                 NaN         NaN
# 4                   PAIN                                 NaN     BICYCLE
# 5                    NaN                                 NaN         NaN
# 8                   PAIN                                 NaN         NaN
# ...                  ...                                 ...         ...
# 114708               NaN                                 NaN  AUTOMOBILE
# 114709               NaN  Passenger Car, Station Wagon, Jeep  AUTOMOBILE
# 114711               NaN  Passenger Car, Station Wagon, Jeep  AUTOMOBILE
# 114712           VISABLE  Passenger Car, Station Wagon, Jeep  AUTOMOBILE
# 114713               NaN                                 NaN  AUTOMOBILE
#
#          veh_make  veh_model police_beat  address_no_primary  ...  \
# 0            FORD        NaN         112                3600  ...
# 1            FORD    MUSTANG         112                3600  ...
# 4             NaN        NaN         611                3500  ...
# 5            FORD     ESCORT         611                3500  ...
# 8       CHEVROLET  SILVERADO         315                   0  ...
# ...           ...        ...         ...                 ...  ...
# 114708       FORD      FOCUS         122                1300  ...
# 114709     NISSAN     SENTRA         122                1300  ...
# 114711      MAZDA    MAZDA 3         613                4100  ...
# 114712      MAZDA    MAZDA 3         613                4100  ...
# 114713     SUBARU     LEGACY         613                4100  ...
#
#        address_sfx_primary address_pd_intersecting address_name_intersecting  \
# 0                BOULEVARD                     NaN                       NaN
# 1                BOULEVARD                     NaN                       NaN
# 4                    DRIVE                     NaN                       NaN
# 5                    DRIVE                     NaN                       NaN
# 8                     ROAD                     NaN                   I-15 SB
# ...                    ...                     ...                       ...
# 114708              AVENUE                     NaN                       NaN
# 114709              AVENUE                     NaN                       NaN
# 114711           BOULEVARD                     NaN                       NaN
# 114712           BOULEVARD                     NaN                       NaN
# 114713           BOULEVARD                     NaN                       NaN
#
#        address_sfx_intersecting violation_section violation_type  \
# 0                           NaN             22107             VC
# 1                           NaN             22107             VC
# 4                           NaN             82.22             MC
# 5                           NaN             82.22             MC
# 8                           NaN            21658A             VC
# ...                         ...               ...            ...
# 114708                      NaN          20002(A)             VC
# 114709                      NaN          20002(A)             VC
# 114711                      NaN             22107             VC
# 114712                      NaN             22107             VC
# 114713                      NaN             22107             VC
#
#                                            charge_desc injured killed  \
# 0               TURNING MOVEMENTS AND REQUIRED SIGNALS       0      0
# 1               TURNING MOVEMENTS AND REQUIRED SIGNALS       0      0
# 4       STOP UPON EMERGING FROM ALLEY/PRIVATE DRIVEWAY       1      0
# 5       STOP UPON EMERGING FROM ALLEY/PRIVATE DRIVEWAY       1      0
# 8       LANED ROADWAYS - STRADDLING OR UNSAFE CHANGING       4      0
# ...                                                ...     ...    ...
# 114708                     HIT AND RUN:PROP DAMAGE (M)       0      0
# 114709                     HIT AND RUN:PROP DAMAGE (M)       0      0
# 114711     TURNS:UNSAFE TURN AND/OR NO TURN SIGNAL (I)       1      0
# 114712     TURNS:UNSAFE TURN AND/OR NO TURN SIGNAL (I)       1      0
# 114713     TURNS:UNSAFE TURN AND/OR NO TURN SIGNAL (I)       1      0
#
#         hit_run_lvl
# 0               NaN
# 1               NaN
# 4               NaN
# 5               NaN
# 8               NaN
# ...             ...
# 114708  MISDEMEANOR
# 114709  MISDEMEANOR
# 114711  MISDEMEANOR
# 114712  MISDEMEANOR
# 114713  MISDEMEANOR
#
# [85104 rows x 22 columns]

# %%
print(multiple_people['report_id'].nunique()) #number of accidents that involve multiple people
# Out:
# 34656

# %%
#check if person_role has any nan
print(traffic_collisions_details_edited['person_role'].isnull().sum())#lets not group by this
print(traffic_collisions_details_edited['violation_section'].isnull().sum())
# Out:
# 3702
# 0

# %%
# count how many missing values in each column for whole dataframe
traffic_collisions_details_edited.isnull().sum()
# Out:
# report_id                         0
# date_time                         0
# person_role                    3702
# person_injury_lvl             89859
# person_veh_type               79448
# veh_type                      63724
# veh_make                      12011
# veh_model                     35908
# police_beat                       0
# address_no_primary                0
# address_pd_primary           113195
# address_road_primary              1
# address_sfx_primary            7069
# address_pd_intersecting      118118
# address_name_intersecting    110039
# address_sfx_intersecting     110912
# violation_section                 0
# violation_type                    0
# charge_desc                       0
# injured                           0
# killed                            0
# hit_run_lvl                   70732
# dtype: int64

# %%
#groupby accident to see how many people involved per accident

n_accident = traffic_collisions_details_edited.groupby('report_id')['violation_section'].count()
print(n_accident)
print(n_accident.max())#max number of people are 15
# Out:
# report_id
# 193502    1
# 193503    2
# 193506    1
# 193508    1
# 193510    1
#          ..
# S00002    1
# T00000    1
# U00000    1
# V00001    1
# V00003    1
# Name: violation_section, Length: 67968, dtype: int64
# 15

# %%
#graph number of people per accident 

n_accident = n_accident.reset_index()
n_accident
# Out:
#       report_id  violation_section
# 0        193502                  1
# 1        193503                  2
# 2        193506                  1
# 3        193508                  1
# 4        193510                  1
# ...         ...                ...
# 67963    S00002                  1
# 67964    T00000                  1
# 67965    U00000                  1
# 67966    V00001                  1
# 67967    V00003                  1
#
# [67968 rows x 2 columns]

# %%
people_graph = sns.histplot(data = n_accident, x = 'violation_section', stat='probability')
people_graph.set_xlabel("Individuals Involved") #most accidents involved 1 person
# Out:
# Text(0.5, 0, 'Individuals Involved')

# %%
#how does an accident involve 1 person
n_accident

one_person = n_accident[n_accident['violation_section']==1] #violation section is what was grouped on
one_person

one_person_details = pd.merge(traffic_collisions_details_edited, one_person, on='report_id')
one_person_details
# Out:
#       report_id            date_time              person_role  \
# 0        600068  2015-01-02 13:04:00                   DRIVER
# 1        600051  2015-01-02 20:15:00  PARKED VEHICLE OCCUPANT
# 2        171111  2015-01-14 20:00:00  PARKED VEHICLE OCCUPANT
# 3        506184  2015-02-19 23:30:00  PARKED VEHICLE OCCUPANT
# 4        506537  2015-03-08 20:00:00  PARKED VEHICLE OCCUPANT
# ...         ...                  ...                      ...
# 33307  22202499  2022-04-23 21:40:00                      NaN
# 33308  22202698  2022-04-29 17:58:00                      NaN
# 33309  22202697  2022-05-06 08:08:00                      NaN
# 33310  22202724  2022-05-07 00:39:05                      NaN
# 33311  22202768  2022-05-09 16:04:51                      NaN
#
#       person_injury_lvl person_veh_type          veh_type  veh_make  \
# 0               VISABLE             NaN        MOTORCYCLE  KAWASAKI
# 1                   NaN             NaN               NaN    TOYOTA
# 2                   NaN             NaN               NaN    TOYOTA
# 3                   NaN             NaN               NaN    B.M.W.
# 4                   NaN             NaN  LIGHT DUTY TRUCK    TOYOTA
# ...                 ...             ...               ...       ...
# 33307               NaN             NaN               NaN       NaN
# 33308               NaN             NaN               NaN       NaN
# 33309               NaN             NaN               NaN       NaN
# 33310               NaN             NaN               NaN       NaN
# 33311               NaN             NaN               NaN       NaN
#
#                   veh_model police_beat  address_no_primary  ...  \
# 0                       NaN         437                2800  ...
# 1      MATRIX (SPORT WAGON)         833                3800  ...
# 2                      RAV4         835                4200  ...
# 3                     328IS         618                1100  ...
# 4                    TACOMA         323                5300  ...
# ...                     ...         ...                 ...  ...
# 33307                   NaN         522                 300  ...
# 33308                   NaN         526                1400  ...
# 33309                   NaN         122                1600  ...
# 33310                   NaN         434                1100  ...
# 33311                   NaN         527                 700  ...
#
#       address_pd_intersecting address_name_intersecting  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# ...                       ...                       ...
# 33307                     NaN                       NaN
# 33308                     NaN                       NaN
# 33309                     NaN                       NaN
# 33310                     NaN                       NaN
# 33311                     NaN                       NaN
#
#       address_sfx_intersecting violation_section_x violation_type  \
# 0                          NaN              21801A             VC
# 1                          NaN               22107             VC
# 2                          NaN            MISC-HAZ             VC
# 3                          NaN               22106             VC
# 4                          NaN               22107             VC
# ...                        ...                 ...            ...
# 33307                      NaN            MISC-HAZ             VC
# 33308                      NaN            MISC-HAZ             VC
# 33309                      NaN            MISC-HAZ             VC
# 33310                      NaN               22107             VC
# 33311                      NaN              21461A             VC
#
#                                              charge_desc injured killed  \
# 0                   LEFT TURN YIELD UNTIL SAFE OR U-TURN       1      0
# 1                 TURNING MOVEMENTS AND REQUIRED SIGNALS       0      0
# 2      MISCELLANEOUS HAZARDOUS VIOLATIONS OF THE VEHI...       0      0
# 3                    STARTING PARKED VEHICLES OR BACKING       0      0
# 4                 TURNING MOVEMENTS AND REQUIRED SIGNALS       0      0
# ...                                                  ...     ...    ...
# 33307  MISCELLANEOUS HAZARDOUS VIOLATIONS OF THE VEHI...       0      0
# 33308  MISCELLANEOUS HAZARDOUS VIOLATIONS OF THE VEHI...       0      0
# 33309  MISCELLANEOUS HAZARDOUS VIOLATIONS OF THE VEHI...       1      0
# 33310        TURNS:UNSAFE TURN AND/OR NO TURN SIGNAL (I)       0      0
# 33311       TRAFFIC CONTROL DEV:DRVR FAILURE TO OBEY (I)       1      0
#
#        hit_run_lvl  violation_section_y
# 0      MISDEMEANOR                    1
# 1      MISDEMEANOR                    1
# 2      MISDEMEANOR                    1
# 3      MISDEMEANOR                    1
# 4      MISDEMEANOR                    1
# ...            ...                  ...
# 33307  MISDEMEANOR                    1
# 33308  MISDEMEANOR                    1
# 33309          NaN                    1
# 33310  MISDEMEANOR                    1
# 33311  MISDEMEANOR                    1
#
# [33312 rows x 23 columns]

# %%
#check violation section for one person accidents

traffic_collisions_dictionary
# Out:
#                         field  \
# 0                   report_id
# 1                   date_time
# 2                 person_role
# 3           person_injury_lvl
# 4             person_veh_type
# 5                    veh_type
# 6                    veh_make
# 7                   veh_model
# 8                 police_beat
# 9          address_no_primary
# 10         address_pd_primary
# 11       address_road_primary
# 12        address_sfx_primary
# 13    address_pd_intersecting
# 14  address_name_intersecting
# 15   address_sfx_intersecting
# 16          violation_section
# 17             violation_type
# 18                charge_desc
# 19                    injured
# 20                     killed
# 21                hit_run_lvl
#
#                                           description  \
# 0                             Collision report number
# 1                              Date/time of collision
# 2       Description of person's role in the collision
# 3             Description of person's level of injury
# 4   Description of type of vehicle (categories def...
# 5                   Description of type of vehicle **
# 6                                 Make of the vehicle
# 7                                Model of the vehicle
# 8                               San Diego Police beat
# 9   Street number of collision location, abstracte...
# 10                    Direction of street in location
# 11                                     Name of street
# 12                                        Street type
# 13  Direction of cross street, if collision at int...
# 14          Street name, if collision at intersection
# 15          Street type, if collision at intersection
# 16     Violation section for primary collision factor
# 17        Violation type for primary collision factor
# 18  Violation section description for primary coll...
# 19              Number of people injured in collision
# 20               Number of people killed in collision
# 21   Level of violation, if collision was a hit & run
#
#                                       possible_values
# 0                                                 NaN
# 1                                                 NaN
# 2   BICYCLIST, DRIVER, OTHER, PARKED VEHICLE OCCUP...
# 3                  FATAL, NULL, PAIN, SEVERE, VISABLE
# 4   see list linked at https://data.sandiego.gov/d...
# 5   AUTOMOBILE, BICYCLE, FARM EQUIPMENT, LIGHT DUT...
# 6                                                 NaN
# 7                                                 NaN
# 8   see list linked at https://data.sandiego.gov/d...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21    Felony or Misdemeanor (Null if not a hit & run)

# %%
#seems like alot of one person accidents are potentially hit/run, lets see those that arent

one_person_details[one_person_details.hit_run_lvl.isnull()]

#question- are all of these collisions-or also tickets?- collisions only presemt

    #1 row per person involved
    #some of these have multiple people listed as injured--mistake or what?
    
one_person_details[ one_person_details.injured >5] #can there be more injured than possible in a vehicle?
# Out:
#       report_id            date_time person_role person_injury_lvl  \
# 4133     600644  2016-01-24 03:14:00      DRIVER               NaN
# 5842     604438  2016-05-13 14:14:00      DRIVER               NaN
# 5906     604424  2016-05-16 12:41:00      DRIVER              PAIN
# 18082    187004  2018-08-31 13:15:00      DRIVER           VISABLE
# 27010  21201529  2021-03-15 09:05:00      DRIVER               NaN
# 31398    180304  2017-12-15 20:22:00         NaN               NaN
#
#                           person_veh_type          veh_type  \
# 4133                                  NaN  LIGHT DUTY TRUCK
# 5842                                  NaN               NaN
# 5906                                  NaN               NaN
# 18082                                 NaN               NaN
# 27010  Passenger Car, Station Wagon, Jeep        AUTOMOBILE
# 31398                                 NaN               NaN
#
#                   veh_make        veh_model police_beat  address_no_primary  \
# 4133                 DODGE              NaN         444                3900
# 5842                 HONDA  CIVIC (AND CRX)         933               13500
# 5906                 DODGE          DURANGO         837                3900
# 18082  GENERAL MOTORS CORP           ACADIA         441                 900
# 27010                VOLVO       240 SERIES         521                1400
# 31398                  NaN              NaN         441                   0
#
#        ... address_pd_intersecting address_name_intersecting  \
# 4133   ...                     NaN                       NaN
# 5842   ...                     NaN                       NaN
# 5906   ...                     NaN                       NaN
# 18082  ...                     NaN                       NaN
# 27010  ...                     NaN                       NaN
# 31398  ...                     NaN                   MILBRAE
#
#       address_sfx_intersecting violation_section_x violation_type  \
# 4133                       NaN               21804             VC
# 5842                       NaN            MISC-HAZ             VC
# 5906                       NaN               22350             VC
# 18082                      NaN               22450             VC
# 27010                      NaN            23153(F)             VC
# 31398                   STREET              21950A             VC
#
#                                              charge_desc injured killed  \
# 4133          ENTERING HWY FROM PRIVATE ROAD OR DRIVEWAY       8      0
# 5842   MISCELLANEOUS HAZARDOUS VIOLATIONS OF THE VEHI...       8      0
# 5906   VIOLATION OF BASIC SPEED LAW, SPEED UNSAFE FOR...       6      0
# 18082                                  STOP REQUIREMENTS       7      0
# 27010                 DUI DRUG:CAUSING BODILY INJURY (F)       7      3
# 31398                  YIELD RIGHT OF WAY TO PEDESTRIANS     180      0
#
#        hit_run_lvl  violation_section_y
# 4133        FELONY                    1
# 5842           NaN                    1
# 5906   MISDEMEANOR                    1
# 18082       FELONY                    1
# 27010          NaN                    1
# 31398          NaN                    1
#
# [6 rows x 23 columns]

# %% [markdown]
# Appears that since a collision can just appear in the data once (one individual/vehicle involved) but injury >1 person that the collisions are reported are the individuals/vehicles at fault. Evidence that supports this is that the violation section is never null.

# %%
pd.set_option('max_columns', None)
print(one_person_details[one_person_details.report_id == '600644'])
# Out:
#      report_id            date_time person_role person_injury_lvl  \
# 4133    600644  2016-01-24 03:14:00      DRIVER               NaN
#
#      person_veh_type          veh_type veh_make veh_model police_beat  \
# 4133             NaN  LIGHT DUTY TRUCK    DODGE       NaN         444
#
#       address_no_primary address_pd_primary address_road_primary  \
# 4133                3900                NaN               MARKET
#
#      address_sfx_primary address_pd_intersecting address_name_intersecting  \
# 4133              STREET                     NaN                       NaN
#
#      address_sfx_intersecting violation_section_x violation_type  \
# 4133                      NaN               21804             VC
#
#                                      charge_desc  injured  killed hit_run_lvl  \
# 4133  ENTERING HWY FROM PRIVATE ROAD OR DRIVEWAY        8       0      FELONY
#
#       violation_section_y
# 4133                    1

# %% [markdown]
# Lets check out injured

# %%
#check numeric columns for maximums and outliers 

traffic_collisions_details_edited[['date_time','injured','killed']].agg(['min','max','mean'])
# Out:
#                 date_time     injured  killed
# min   2015-01-01 15:19:00    0.000000  0.0000
# max   2022-05-10 01:40:00  180.000000  4.0000
# mean                  NaN    0.731151  0.0057

# %%
#seems like outlier in max injured..very unlikely 

outliers = traffic_collisions_details_edited[traffic_collisions_details_edited['injured']>10]
outliers
# Out:
#        report_id            date_time person_role person_injury_lvl  \
# 47059     184523  2018-06-12 14:22:00      DRIVER               NaN
# 47060     184523  2018-06-12 14:22:00      DRIVER              PAIN
# 116502    180304  2017-12-15 20:22:00         NaN               NaN
#
#        person_veh_type veh_type veh_make veh_model police_beat  \
# 47059              NaN      NaN    LEXUS       NaN         931
# 47060              NaN      NaN    ACURA        TL         931
# 116502             NaN      NaN      NaN       NaN         441
#
#         address_no_primary address_pd_primary address_road_primary  \
# 47059                 6300                NaN              MIRAMAR
# 47060                 6300                NaN              MIRAMAR
# 116502                   0                NaN           OCEAN VIEW
#
#        address_sfx_primary address_pd_intersecting address_name_intersecting  \
# 47059                 ROAD                     NaN                       NaN
# 47060                 ROAD                     NaN                       NaN
# 116502           BOULEVARD                     NaN                   MILBRAE
#
#        address_sfx_intersecting violation_section violation_type  \
# 47059                       NaN             22107             VC
# 47060                       NaN             22107             VC
# 116502                   STREET            21950A             VC
#
#                                    charge_desc  injured  killed hit_run_lvl
# 47059   TURNING MOVEMENTS AND REQUIRED SIGNALS      122       0         NaN
# 47060   TURNING MOVEMENTS AND REQUIRED SIGNALS      122       0         NaN
# 116502       YIELD RIGHT OF WAY TO PEDESTRIANS      180       0         NaN

# %%
print(len(traffic_collisions_details_edited))
# Out:
# 118416

# %%
#get rid of outliers

#since unique index

traffic_collisions_details_edited.drop(outliers.index, axis=0, inplace=True)

# %%
print(len(traffic_collisions_details_edited))
# Out:
# 118413

# %%
sns.histplot(data = traffic_collisions_details_edited, x ='injured', stat = 'probability')
# Out:
# <AxesSubplot:xlabel='injured', ylabel='Probability'>

# %%
sns.histplot(data = traffic_collisions_details_edited, x = 'killed', stat='probability')
# Out:
# <AxesSubplot:xlabel='killed', ylabel='Probability'>

# %% [markdown]
# Now lets see vehicle type

# %%
#person_veh_type versus #veh_type

print(traffic_collisions_details_edited['person_veh_type'].unique())

print(traffic_collisions_details_edited['veh_type'].unique())
# Out:
# [nan 'Passenger Car, Station Wagon, Jeep' 'Paratransit' 'Pickups & Panels'
#  'Unknown Hit and Run Vehicle' 'Three or More Axle Truck' 'Ambulance'
#  'Police Car' 'Sport Utility Vehicle' 'Mini-vans' 'Other Commercial'
#  'All Terrain Vehicle' 'Two Axle Truck' 'Public Transit Authority'
#  'Motor Driven Cycle/Scooter' 'Motorcycle' 'Fire Truck'
#  'Emergency Vehicle (On Emg Run)' 'Two Axle Tank Truck' 'Pickup w/Camper'
#  'Low Speed Vehicle' 'Tour Bus' 'Truck Tractor' 'Non-Commercial Bus'
#  'Passengers' 'Utility' 'Misc Mtr Veh (Snowmbl,Glf Crt)'
#  'Go-ped, ZIP Elec sctr, Motobrd' 'Semi' 'Three Axle Tank Truck'
#  'Mobile Equipment' 'Bicycle' 'Motor Home'
#  'Two Trailers (includes Semi & Pull)'
#  'Federally Legal Double Combo Over 75 Feet' 'Two-Axle Tow Truck'
#  'HazWst Three or More Axle Trk' 'School Bus Public Type I'
#  'School Bus Private Type I' 'General Public Paratransit Vehicle'
#  'Semi Tank Trailer' 'School Bus Public Type II' 'Motorized Bicycle'
#  'Pull' 'Boat' 'Misc Non-Motor Vehicle' 'Federally Legal Semi'
#  'HazMat Two-Axle Truck' 'Hwy. Construction Equip.' 'Three-Axle Tow Truck'
#  'Fork Lift' 'HazWst Three-Axle Tank Truck'
#  'HazMat Three or More Axle Trk' 'Pedestrian' 'HazWst Two-Axle Truck'
#  'Police Motorcycle' 'Trailer Coach' 'Motor-Home > 40 Feet'
#  'HazMat Pass Car, Stn Wgn, Jeep' 'Farm Labor Vehicle (Certified)'
#  'HazMat Truck Tractor' 'HazWst Truck Tractor'
#  'School Bus Private Type II']
# [nan 'MOTORCYCLE' 'BICYCLE' 'LIGHT DUTY TRUCK' 'AUTOMOBILE'
#  'MOTORCYCLE          ' 'BICYCLE             ' 'TRUCK               '
#  'AUTOMOBILE          ' 'TRAILER' 'TRUCK' 'FARM EQUIPMENT'
#  'UNLISTED CONSTRUCTION EQUIPMENT' 'TRAILER             ' 'AIRCRAFT'
#  'AIRCRAFT            ' 'ALL TERRAIN VEHICLE' 'ALL TERRAIN VEHICLE ']

# %%
#change datetime to actual datetime data type to do time series analysis 

traffic_collisions_details_edited['date_time'] = pd.to_datetime(traffic_collisions_details_edited['date_time'])

# %%
print(traffic_collisions_details_edited['date_time'].iloc[0].date())
# Out:
# 2015-01-01

# %%
#make year, month, day column separate 
print(traffic_collisions_details_edited['date_time'].iloc[0].hour)
# Out:
# 15

# %% [markdown]
# Now lets see what violation sections are most prominent- what is mostly causing these collisions

# %%
#violation section

print(traffic_collisions_details_edited['violation_section'].unique())
# Out:
# ['22107' '21801A' '82.22' 'MISC-HAZ' '22106' '21658A' '21651B' '21950B'
#  '21950A' '22350' '21460A' '21703' '21804' '21651A' '21954A' '22100A'
#  '21954(B)' '21802A' '21453A' '22515A' '21955' '21453C' '22450(A)'
#  '21800A' '21663' '22453' '23152A' '20002(A)' '21952' 'UNKNOWN' '22105'
#  '21461A' '22100B' '21754' '84.09' '22109' '21750' '21801B' '21650'
#  '21657' '22102' '21460.5C' '21451A' '21456B' '21956' 'MISC' '21650.1'
#  '21463' '21705' '21755' '23103' '21453B' '22517' '20002(B)' '21800C'
#  '84.12' '21803A' '22349' '22515B' '21717' '21202A' '21806A' '21800B'
#  '24250' '21208A' '21457A' '21753' '21803B' '21800(D)1' '21453D'
#  '21760(C)' '22400A' '22101D' '24002' '22108' '12500(A)' '23114(A)'
#  '23109(C)' '22103' '21651(A)(2)' '21800E' '26451A' '22450' '21702A'
#  '23104' '21651(A)1' '21209A' '84.09A' '23123(A)' '981154' '21711'
#  '20002(A)(1)' '26450' '20002(A)(2)' '2800.2(A)' '24400' '22500E' '21957'
#  '27315E' '21201A' '21461.5' '22352' '23153' '21651(C)' '21701' '21200.5'
#  '21752A' '21951' '2800.1(A)' '35251(A)' '4000(A)(1)' '22500G' '21703A'
#  '21970(A)' '21953' '21201D' '22451B' '21451B' '23106' '21708' '21712A'
#  '21456(A)' '84.09B' '23110A' '21706' '487H(A)' '23123.5(A)' '20001(A)'
#  '21700' '22526(D)' '23152(E)' '22526A' '22651(H)(1)' '655.7' '22650'
#  '21800(D)(1)' '22658A' '23136' '22451A' '21751' '16025A' '22359' '10851'
#  '22349(A)' '22456' '22655A' '21966' '21950C' '12500B' '22655.5' '38314'
#  '21802B' '26708A' '215(A)' '23152(F)' '12500' '21212(A)' '23109(A)'
#  '2818' '2803(A)' '22515' '21660' '21707' '21367C' '38300' '21752D'
#  '23152B' '21462' '14607' '22100.5' '2800.4' '21203' '26451B' 'GANGS'
#  '21228' '21755(A)' '22655.5(B)' '22651F' '21712B' '22651B' '23152(G)'
#  '22356' '21800(D)' '21367(B)' '21367(A)' '22500A' '84.05' '21960A'
#  '21456.2(A)' '21235(A)' '21964' '21235(I)' '21235(G)' '21205' '21211'
#  '21235(B)' '21235(C)' '21456(C)' '35250' '21209' '21460(C)' '23152C'
#  '21652' '23115' '26454A' '22348A' '22411' '21460B' '21229(A)' '21200B'
#  '11350(A)' '23153(A)' '10851(A)' 'MISC-NONHAZ' '23153(F)' '21221.5'
#  '21100.3' '21235(E)' '38355' '26451' '14601.1(A)' '26453' '14603'
#  '21809(A)' '14601(A)' '2800' '22651O1A' '21456.3(C)' '21204B' '21208(B)'
#  '20001(B)(1)' '21458(A)(1)' '22500H' '21656' '21760' '14601.2(A)'
#  '22502A' '23124(A)' '23550(A)' '22655' '22653(B)' '21655B' '16028A'
#  '21456.3(A)' '22450(B)' '21658B' '27501B' '21201(D)(2)' '38305' '21454C'
#  '21106B' '23154(A)' '21113A' '29004A' '38330' '22349(B)' '23153(G)'
#  '22526(C)' '27315D' '20003(A)' '31' '22110(B)' '23116A' '38312' '21210'
#  '21712(H)' '22405(A)' '22651C' '23153(B)' '16028(C)' '38320A' '21963'
#  '21201(D)(1)' '29003A' '22504A' '21253' '23140A' '22651G' '16500.5A1'
#  '21457B' '23152D' '21655.8' '22651P' '22348C' '22500I' '23105A' '38304'
#  '2800.3' '23109.2A1' '21204A' '23102A' '63.0102B1' '22500F' '21456A'
#  '29003B' '21229(B)' '38316' '27801A' '24008.5']

# %%
#charge description

print(traffic_collisions_details_edited['charge_desc'].unique()) #these repeat
# Out:
# ['TURNING MOVEMENTS AND REQUIRED SIGNALS'
#  'LEFT TURN YIELD UNTIL SAFE OR U-TURN'
#  'STOP UPON EMERGING FROM ALLEY/PRIVATE DRIVEWAY'
#  'MISCELLANEOUS HAZARDOUS VIOLATIONS OF THE VEHICLE CODE'
#  'STARTING PARKED VEHICLES OR BACKING'
#  'LANED ROADWAYS - STRADDLING OR UNSAFE CHANGING'
#  'DRIVE THE WRONG WAY ON A DIVIDED HIGHWAY'
#  'PEDESTRIAN NOT TO SUDDENLY ENTER PATH, ETC'
#  'YIELD RIGHT OF WAY TO PEDESTRIANS'
#  'VIOLATION OF BASIC SPEED LAW, SPEED UNSAFE FOR CONDITIONS'
#  'DRIVING TO LEFT OF DOUBLE SOLID LINES' 'FOLLOWING TOO CLOSELY'
#  'ENTERING HWY FROM PRIVATE ROAD OR DRIVEWAY'
#  'DIVIDED HIGHWAYS DRIVING TO LEFT OF DIVIDING SECTION OR U-TURN'
#  'PEDESTRIANS OUTSIDE CROSSWALKS' 'RIGHT TURNS AT INTERSECTIONS'
#  'DRIVER CARE ON ROADWAY'
#  'ENTRANCE FROM STOP THROUGH HIGHWAY,YIELD UNTIL REASONABLY SAFE'
#  'RED OR STOP,VEHICLES STOP AT LIMIT LINE' 'LEAVE VEHICLE UNATTENDED'
#  'CROSSING BETWEEN CONTROLLED INTERSECTIONS'
#  'RED ARROW,DO NOT ENTER INTERSECTION' 'STOP REQUIREMENTS STATE STOP LINE'
#  'UNCONTROLLED INTERSECTION,YIELD TO FIRST VEHICLE WITHIN'
#  'DRIVING ON SIDEWALKS' 'EFFECT OF NEGLIGENCE ON PASSENGERS'
#  'DUI ALCOHOL AND/OR DRUGS' 'HIT AND RUN' 'RIGHT OF WAY ON SIDEWALK'
#  'UNKNOWN/INVALID CHARGE' 'TURNING ON CURVE OR CREST OF GRADE'
#  'FAIL TO OBEY TRAFFIC CONTROL DEVICE'
#  'MISC CITY/COUNTY MISDEMEANOR ORDINANCES' 'LEFT TURNS AT INTERSECTIONS'
#  'PASSING ON RIGHT,WHEN UNLAWFUL' 'BICYCLE RIDING RESTRICTED'
#  'SIGNAL WHEN STOPPING' 'OVERTAKE AND PASS TO LEFT'
#  'FAILURE TO YIELD,TURNING VEHICLE HAVING YIELDED'
#  'FAILURE TO DRIVE ON RIGHT SIDE OF ROADWAY' 'OFF-CENTER LANES'
#  'U-TURN IN BUSINESS DISTRICT' 'LEFT TURN LANE'
#  'VEHICULAR TRAFFIC, GREEN LIGHT' "PEDESTRIAN TRAFFIC, 'WAIT' SIGN"
#  'PEDESTRIAN ON ROADWAY' 'BICYCLE DRIVING ON WRONG SIDE OF ROAD'
#  'ILLEGAL OPERATION OF SIGNALS' 'CARAVANS' 'PASS ON THE RIGHT SAFELY'
#  'RECKLESS DRIVING' 'AFTER STOPPING YIELD TO PEDESTRIANS'
#  'OPENING AND CLOSING DOORS'
#  'HIT AND RUN BY RUNAWAY VEHICLE:PROPERTY DAMAGE'
#  'FOUR-WAY STOP, YIELD RIGHT'
#  'SKATEBOARDING/SKATING/ON STREET/SIDEWALK/PLAZA/PARKADE PROHIB'
#  'YIELD SIGNS,YIELD UNTIL REASONABLY SAFE'
#  'DRIVE OVER MAXIMUM SPEED LIMIT'
#  'LEAVING BRAKES OFF ON UNATTENDED AUTOMOBILE'
#  'MOTOR VEHICLE CROSSING BICYCLE LANE'
#  'BICYCLIST, FAILURE TO USE RIGHT EDGE ROAD'
#  'YIELD RIGHT OF WAY TO EMERGENCY VEHICLE'
#  'UNCONTROLLED INTERSECTION,YIELD TO VEHICLE ON RIGHT'
#  'LIGHTING DURING DARKNESS' 'BICYCLIST TO USE BICYCLE LANE'
#  'FLASHING RED, FAILING TO STOP FOR' 'YIELDING FOR PASSING'
#  'FAILURE TO YIELD, BY VEHICLE NOT A HAZARD'
#  'WHEN LIGHT IS INOPERABLE DRIVER NEEDS TO STOP'
#  'PEDESTRIAN TRAFFIC, RED LIGHT'
#  'UNSAFE PASSING WITHIN THREE FEET OF BICYCLIST' 'MINIMUM SPEED LAW'
#  'OBEDIENCE TO OFFICIAL TRAFFIC CONTROL' 'OPERATING UNSAFE VEHICLE'
#  'DURATION OF SIGNAL' 'DRIVE W/O LICENSE'
#  'SPILLING LOAD, OTHER THAN CLEAR WATER AND FEATHERS FROM BIRDS'
#  'AID/ABET/ENGAGE IN MOTOR VEHICLE EXHIBITION OF SPEED'
#  'U-TURN IN RESIDENCE DISTRICT'
#  'DIVIDED HIGHWAYS - UNLAWFUL LEFT, SEMICIRCLE, OR U-TURN'
#  'FAILURE TO STOP FOR INOPERATIVE SIGNAL LIGHTS' 'PARKING BRAKE SYSTEM'
#  'STOP REQUIREMENTS' 'DRIVING HOURS-PERSONS, NOT TO EXCEED 10 HOURS'
#  'RECKLESS DRIVING W/INJURY' 'DRIVE ACROSS DIVIDING SECTION'
#  'DRIVING IN THE BICYCLE LANE'
#  'BICYCLE RIDING SIDEWALK OF BUSINESS DISTRICT PROHIB'
#  'USE OF CELL PHONE W/O HANDS FREE DEVICE WHILE DRIVING'
#  'MISCELLANEOUS REPORTS (TRAFFIC) - 153'
#  'TOWED VEHICLE,WHIPPING, SWERVING, ETC.'
#  'HIT & RUN PROPERTY DAMAGE:LOCATE/ETC OWNER REQUIREMENTS'
#  'REQUIRED BRAKE SYSTEMS'
#  'EVADE PEACE OFFICER WITH WANTON DISREGARD FOR SAFETY'
#  'LOCATION AND NUMBER OF LIGHTED HEADLIGHTS'
#  'PROHIBITED STOPPING, STANDING, OR PARKING' 'HITCHHIKING'
#  'PERSON OVER 15 RIDING AS PASSENGER IN VEHICLE W/O SAFETY BELT'
#  'SELLING BICYCLE WITHOUT APPROVED REFLECTORS'
#  'OBEDIENCE TO OFFICIAL TRAFFIC CONTROL DEVICE (PEDESTRIAN)'
#  'PRIMA FACIE SPEED LIMITS' 'DRIVING UNDER THE INFLUENCE W/ INJURY'
#  'DRIVE THE WRONG WAY ON A DIVIDED HIGHWAY: CAUSE INJ OR DEATH'
#  'INTERFERENCE WITH DRIVER OR MECHANISM'
#  'RIDING BICYCLE WHILE UNDER INFLUENCE OF ALCOHOL/DRUGS'
#  'DRIVING LEFT OF CENTER,VIEW LIMITED BY CURVE OR HILL CREST'
#  'VEHICLES STOPPED FOR PEDESTRIANS' 'EVADING PEACE OFFICER'
#  'UNSECURED BOOM/MAST (I)' 'FOLLOW TOO CLOSELY'
#  'STOP VEHICLE UNNECESSARILY, CAUSE BLOCKAGE OF MRKD/UNMRKD X-WALK'
#  'TUNNEL OR OVERHEAD CROSSING'
#  'OPERATING BIKE W/O FRONT LIGHT, SIDE/REAR/PEDAL REFLECTORS'
#  'OBEDIENCE TO SIGNAL DEVICE, FLAGMAN, ETC.'
#  'PEDESTRIAN TRAFFIC, GREEN LIGHT OR VEH GREEN ARROW'
#  'DRIVING UNDER INFLUENCE DRUGS W/INJURY'
#  'RUNNING OVER FIRE OR CHEMICAL HOSE'
#  'PERMITTING UNLAWFUL RIDING ON VEHICLE'
#  'TRANSFER OF OWNERSHIP ON VEHICLE'
#  'BICYCLE RIDING HAZARDOUSLY W/O YIELDING TO PEDESTRIANS'
#  'THROW SUBSTANCE AT VEHICLE' 'FOLLOWING FIRE DEPARTMENT VEHICLES'
#  'GRAND THEFT: CARGO EXCEEDS $950' 'TEXT MESSAGING WHILE DRIVING'
#  'HIT AND RUN DEATH OR INJURY' 'OBSTRUCTION TO DRIVING'
#  'ENTER RAILROAD CROSSING W/O CLEARANCE (I)' 'DUI DRUGS (M)'
#  'BLOCKING INTERSECTION' 'DRIVER ARRESTED'
#  'OPERATION OF PERSONAL WATERCRAFT'
#  'UNLAWFUL REMOVAL OF UNATTENDED VEHICLE'
#  'APPROACHING INTERSECTION WITH INOPERATIVE SIGNALS.'
#  'VEHICLE REMOVAL FROM PRIVATE PROP'
#  'DUI:UNDER 21YR W/BA.01 (ZERO TOLERANCE) (I)'
#  'OBEDIENCE TO SIGNAL DEVICE, FLAGMAN, ETC., AT RR CROSSING'
#  'PASSING WITHOUT SUFFICIENT CLEARANCE'
#  'FAILURE TO EXCHANGE INSURANCE INFORMATION  - VEHICLE ACCIDENT (I)'
#  'BOUNDARY LINE STREETS' "TAKE VEHICLE W/O OWNER'S CONSENT/VEHICLE THEFT"
#  'DRIVE OVER MAXIMUM SPEED LIMIT OF 65'
#  'IMPOUND VEHICLE FOR HIT AND RUN INVESTIGATION'
#  'NO PEDESTRIAN - BICYCLE LANE WHERE PEDESTRIAN FACILITY'
#  'USING CAUTION APPROACHING A PEDESTRIAN WITHIN ANY MARKED OR UNMARKED CROSSWALK'
#  'LICENSED DRIVER, OUT OF CLASSIFICATION'
#  'IMPOUNDING OF A VEHICLE FOR EVIDENCE'
#  'NO UNSAFE MOVE FROM DIRECT COURSE-RIGHT OR LEFT'
#  'FAILURE TO YIELD,BY VEHICLE NOT A HAZARD'
#  'STICKERS, OBJECTS OBSTRUCTING VIEW' 'CARJACKING' 'DUI DRUGS'
#  'OPERATING A BICYCLE ON A ROADWAY WITHOUT AN  EQUIPPED BRAKE'
#  'RIGHT-OF-WAY:INTERSECTION' 'DUI ALCOHOL'
#  'UNLAWFUL TO DRIVE UNLESS LICENSED'
#  'HELMET REQUIRED FOR MINOR RIDING BICYCLE'
#  'ENGAGE IN A MOTOR VEHICLE SPEED CONTEST' 'DRIVING THROUGH FLARE PATTERN'
#  'VIOLATION OF LOAD REGULATIONS' 'UNATTENDED VEHICLES'
#  'APPROACHING VEHICLES' 'INTERFERENCE WITH FIRE DEPARTMENT VEHICLES'
#  'FAILURE TO OBEY WARNING DEVICES AT CONSTRUCTION SITE'
#  'OFF-HIGHWAY VEHICLE DISOBEYING SIGN, SIGNAL, TRAFFIC CONTROL'
#  'DRIVING LEFT OF CENTER,TRAVERSING INTERSECTION'
#  'DUI ALCOHOL 0.08 PERCENT' 'OBEDIENCE TO TRAFFIC CONTROL SIGNALS'
#  'PERMITTING UNLICENSED MINOR TO DRIVE'
#  'U-TURN AT CONTROLLED INTERSECTION'
#  'EVADING A PEACE OFFICER:WRONG WAY DRIVER'
#  'BICYCLIST, HITCHING RIDE WITH OTHER VEHICLE' 'GANG RELATED OFFENSE'
#  'PERSON OPERATING A MOTORIZED SCOOTER UPON A HIGHWAY'
#  'REMOVE/IMPOUNDING VEHICLE THAT IS OR CONTAINS EVIDENCE'
#  'VEHICLE UNATTENDED ON FREEWAY OVER 4 HOURS'
#  'UNLAWFUL RIDING BY PASSENGER' 'VEHICLE CREATE HAZARD ON HIGHWAY'
#  'DUI ALCOHOL AND DRUGS' 'MAXIMUM SPEED 65 MPH, WHEN SIGN POSTED'
#  'STOP FOR INOPERATIVE TRAFFIC CONTROL SIGNALS'
#  'DISOBEY TRAFFIC CONTROL CONSTRUCTION SITE'
#  'TRAFFIC CONTROL - HIGHWAY CONSTRUCTION' 'DISORDERLY CONDUCT: ALCOHOL'
#  'FOLLOWING TOO CLOSELY (I)' 'VEHICLE OBSTRUCTING CROSSWALK/STREET'
#  'UNSAFE SPEED (BASIC SPEED LAW) (I)' 'PEDESTRIAN ON FREEWAY'
#  'BICYCLIST MUST OBEY RULES OF THE ROAD (I)'
#  'TURNS:UNSAFE TURN AND/OR NO TURN SIGNAL (I)'
#  'OPERATE MOTORIZED SCOOTER WITHOUT ADEQUATE BRAKES'
#  'CARRYING WHITE CANE BY OTHER THAN BLIND PERSON'
#  'LEAVE MOTORIZED SCOOTER ON SIDEWALK BLOCKING PEDESTRIAN TRAFFIC'
#  'OPERATE MOTORIZED SCOOTER UPON A SIDEWALK'
#  'BICYCLIST, AT LEAST ONE FREE HAND'
#  'DUI ALCOHOL:  0.04% OR MORE WHILE DRIVING PASSENGER FOR HIRE'
#  'BLOCKING THE BICYCLE LANE'
#  'DUI ALCOHOL: 0.04% OR MORE WHILE DRIVING PASSENGER FOR HIRE'
#  'OPERATE MOTOR SCOOTER ON HGHWY W/POSTED SPEED > 25MPH'
#  'OPERATE MOTORIZED SCOOTER WITHOUT PROPER/FASTENED HELMET'
#  'SIGNAL LIGHTS:CIRCULAR RED (I)' 'UNSAFE START ON HWY (I)'
#  'PEDESTRIAN CROSS AT WALK SIGNAL MUST PROCEED TO SIDEWALK (I)'
#  'RIGHT-OF-WAY:FROM STOP INTERSECTION (I)'
#  'FAIL TO STOP FOR SIGNAL LOCATED AWAY FROM INTERSECTION'
#  'MAXIMUM HEIGHT VEHICLE' 'MOTOR VEHICLE NOT BE DRIVEN IN BICYCLE LANE'
#  "DRVG WITHOUT VALID DRVR'S LIC (M)" 'TURNS:FAIL TO OBEY TURN SIGNS (I)'
#  'LANE USAGE: SOLID/BROKEN DOUBLE YELLOW LINE VIOL (I)'
#  'RIGHT-OF-WAY:MAKING LEFT OR U-TURN (I)'
#  'PASSING:UNSAFE PASSING:SAME DIRECTION (I)' 'ADDICT DRIVE VEHICLE'
#  'DUI ALCOHOL/DRUG (M)' 'UNSAFE OPENING OF VEH DOOR (I)'
#  'ENTRANCE TO PUBLIC HIGHWAY FROM SERVICE ROAD'
#  'RIGHT-OF-WAY:DRVR YIELD TO PEDESTRIAN IN CROSSWALK (I)'
#  'TRAFFIC CONTROL DEV:DRVR FAILURE TO OBEY (I)'
#  'LANE USAGE:UNSAFE LANE CHANGE (I)'
#  'OPERATE MOTOR SCOOTER UPON SIDEWALK (I)' 'HIT AND RUN:PROP DAMAGE (M)'
#  'RUBBISH VEHICLES TO COVER LOAD' 'OPER MOTOR SCOOTER W/O HELMET (I)'
#  'SIGNAL LIGHTS:CIRCULAR GREEN (I)' 'STOPPING DISTANCE REQUIREMENTS'
#  'RIGHT-OF-WAY: ENTERING OR CROSSING INTERSECTION (I)'
#  'EXCEED SPEED LIMIT AS SET IN VC 22349 OR VC 22356 (I)'
#  'SPEED LIMIT - MOTORIZED SCOOTERS'
#  'DRIVING TO LEFT OF SOLID-BROKEN LINES'
#  'OPERATE MOTOR SCOOTER IN BICYCLE LANE'
#  'EVADE PEACE OFCR WITH WANTON DISREGARD FOR SAFETY (F)'
#  'LANE USAGE:DIV HWY:DRIVE ON DIV SECTION OR U-TURN (I)'
#  'POSSESSION OF NARCOTIC CONTROLLED SUBSTANCES (M)'
#  'FAIL TO SET BRAKE:UNATTENDED MOT VEH (I)'
#  'DUI ALCOHOL:CAUSING BODILY INJURY (M)'
#  'RIGHT-OF-WAY - CONTROLLED BY STOP SIGHNS - LEFT DRIVER YIELD (I)'
#  'SIGNAL LIGHTS:RIGHT TURN ON RED (I)' 'DUI ALC/0.08 PERCENT (M)'
#  'PEDESTRIAN CROSS AGAINST NO WALK SIGN/SIGNAL (I)'
#  'LANE USAGE:FAIL TO DRIVE ON RIGHT HALF OF ROAD (I)'
#  'UNSAFE TURNING MOVEMENT (I)' 'SIGNAL LIGHTS:RED ARROW (I)'
#  "TAKE VEHICLE W/O OWNER'S CONSENT/VEHICLE THEFT (F)"
#  'OPER MOTORCYCLE W/O PROPER LIC (I)' 'FAILED TO STOP FOR STOP SIGN (I)'
#  'RIGHT-OF-WAY:TO EMERGENCY VEH (I)'
#  'LANE USAGE:OPERATING BICYCLE ON WRONG SIDE OF ROAD (I)'
#  'RIGHT-OF-WAY:PED NOT IN CROSSWALK YIELD TO VEHS (I)'
#  'RIGHT-OF-WAY:ENTERING HWY (I)' 'DUI ALCOHOL (M)' 'JAYWALKING (I)'
#  'HIT AND RUN:RUNAWAY VEH:PROP DAMAGE (M)'
#  'MOTORIZED SCOOTER SHALL RIDEIN BIKE LANE (I)'
#  'DRIVE OVER, UPON, OR ACROSS DIVIDING SECTION OF HIGHWAY (I)'
#  'LANE USAGE:2-WAY LEFT TURN LANE (I)'
#  'MISCELLANEOUS NON-HAZARDOUS VIOLATIONS OF THE VEHICLE CODE'
#  'FAIL TO RIDE BICYCLE:RIGHT EDGE OF ROADWAY (I)'
#  'LANE USAGE:VEH CROSS DOUBLE SOLID LINE (I)'
#  'HIT AND RUN RESULTING IN DEATH OR INJURY(IBR 90Z)'
#  'TURNS:IMPROPER LEFT HAND TURN (I)'
#  'RIGHT-OF-WAY:DRVR YIELD TO PEDESTRIAN ON SIDEWALK (I)'
#  'EVADING PEACE OFFICER (M)'
#  'PED IN CROSSWALK: STOP/DELAY VEHICLES OR SUDDENLY LEAVE PLACE OF SAFETY (I)'
#  'TURNS:ILLEGAL U-TURN IN A RES DISTRICT (I)'
#  'DUI ALCOHOL/DRUGS:CAUSING BODILY INJURY (M)'
#  'PASSING:UNSAFE PASSING ON RIGHT OR ON SHOULDER (I)'
#  'OPER MOTOR SCOOTER UNDER INFL OF ALC/DRUGS (M)'
#  'UNLAWFUL DRVG Mot Veh IN BICYCLE LANE (I)' 'DRVG ON SIDEWALK (I)'
#  'RIGHT-OF-WAY:INTERSECTION - LEFT DRIVER YIELD (I)'
#  'SIGNAL LIGHTS:FLASHING RED (I)'
#  'RIGHT-OF-WAY:FROM YIELD INTERSECTION (I)'
#  'LANE USAGE:DISOBEY DESIGNATED TRAFFIC DIRECTION Dev (I)'
#  'FAIL TO OBEY LOCAL TRAFFIC REGULATOR (I)'
#  'TRAFFIC CONTROL Dev:PEDESTRIAN FAILURE TO OBEY (I)'
#  'OPERATE UNSAFE OR NOT SAFELY LOADED VEHICLE; IMMEDIATE SAFETY HAZARD (I)'
#  'DUI ALCOHOL:CAUSING BODILY INJURY (F)'
#  'OPERATE MOTORIZED SCOOTER WITH ADDED PASSENGER(S)'
#  'USE CELL PHONE WHILE DRIVING WITHOUT HANDSFREE DEVICE (I)'
#  'NOT EQUIPPED WITH WORKING BRAKE SYSTEM (I)'
#  'PARKING BRAKE OPERATIONS (I)' "DRVG WITHOUT VALID DRVR'S LIC (I)"
#  'TURNS:IMPROPER RIGHT HAND TURN (I)' 'VEHICLE OR LOAD EXCEED 14 FEET (I)'
#  'DRVG WHILE LIC SUSP OR REVOKED:OTHER REASONS (M)'
#  'BRAKE SYSTEM COND VIOL (I)'
#  'RIGHT-OF-WAY:INOPERATIVE SIGNAL:STOP/YIELD AT LIMIT LINE (I)'
#  'FAIL TO RIDE MOTOR SCOOTER:RIGHT EDGE OF ROADWAY (I)'
#  'DRIVE TOO SLOWLY/IMPEDING TRAFFIC (I)'
#  'DRIVER TO EXERCISE DUE CARE FOR THE SAFETY OF PEDS ON ROADWAY (I)'
#  'DRVG WHILE LIC SUSP OR REVOKED:OTHER REASONS (I)'
#  'OPER VEH:VIOL OF LIC RESTRICTION (I)'
#  'CHANGE LANE FOR EMERGENCY VEHICLE (I)' 'SUDDEN STOP W/O SIGNALING (I)'
#  'DRVG WHILE LIC SUSP OR REVOKED (M)'
#  'LANE USAGE:DIV HWY:DRIVE WRONG SIDE OF BARRIER (M)'
#  'IMPROP VEH:SPILL/ETC:HWY (M)' 'PASSING:PASS W/O ENOUGH CLEARANCE (I)'
#  'RIGHT-OF-WAY:PED NOT IN CROSSWALK YIELD TO VEHS (M)'
#  'MUST STOP NOT LESS THAN 15 FEET FROM NEAREST RAIL (I)'
#  'FAIL TO OBEY PEACE OFFICER:LAWFUL ORDER OR INSPECTION (M)'
#  'VEHICLE REGISTRATION EXPIRED OVER 6 MONTHS (I)'
#  'BICYCLE MUST STOP BEFORE INTERSECTION AT RED LIGHT (I)'
#  'SHALL NOT PROCEED THROUGH, AROUND, UNDER CLOSED CROSSING GATE (I)'
#  'PASSING: UNSAFE PASSING ON RIGHT OR ON SHOULDER (I)'
#  'BICYCLE PASSENGER NOT SEATED (I)'
#  'PROHIBIT TEXT-BASED COMMUNICATION WHILE DRIVING (I)'
#  'BIKE LANE - UNSAFE MOVEMENT (I)' 'UNLAWFUL LEFT OR U-TURN (I)'
#  'BRAKES REQUIRED ON BICYCLE (I)' 'DUI DRUG (M)'
#  'HIT AND RUN RESULTING IN INJURY(IBR 13A)'
#  'OPERATE MOTOR SCOOTER WITH PASSENGERS (I)'
#  'OTHER AGENCY VEHICLE THEFT/RECOVERY (F)'
#  'OPER MOTOR SCOOTER:HWY:VIOL (I)' 'PARK, STOP OR STAND IN RED ZONE (I)'
#  'RECKLESS DRVG:HWY (M)' 'DISREGARD SAFETY:EVADE POLICE (M)'
#  'LANE USAGE:DIV HWY:DRIVE WRONG SIDE OF BARRIER:INJ/DEATH (F)'
#  'FAIL TO SET BRAKE:UNATTENDED VEH (I)'
#  'DUI DRUG:CAUSING BODILY INJURY (F)' 'PARK UNLAWFULLY:DOUBLE PARKING (I)'
#  'TURNING OUT, SLOW MOVING VEHICLES' 'EXCEED 15 MPH:MOTOR SCOOTER (I)'
#  'PEDESTRIAN ON FREEWAY (I)' 'THREE FEET FOR SAFETY ACT (I)'
#  'DRIV W/LIC SUSP/REV W/PRIOR DUI CONV (M)'
#  'PARKING:PARALLEL PARK:RT SIDE WITHIN 18 OF CURB (I)"'
#  'EXCEED PRIMA FACIE SPEED (I)'
#  'USE CELL PHONE WHILE DRIVING:UNDER 18 YEARS OLD (I)'
#  'FAIL COVER RUBBISH VEH LOAD (I)'
#  'TURNS:ILLEGAL U-TURN IN A BUSINESS DISTRICT (I)'
#  'DUI W/PRIOR SPECIFIC CONVICTIONS (F)'
#  'SIGNAL LIGHTS:PEDESTRIAN CIRCULAR RED OR RED ARROW (I)'
#  'HIT AND RUN INVESTIGATION (I)'
#  'PASSING:UNLAWFUL PASSING ON THE RIGHT (I)'
#  'VEHICLE ON PRIVATE PROPERTY - INVOLVED IN ACCIDENT (I)'
#  'LANE USAGE:SPECIAL VEH IN WRONG LANE (I)'
#  'SIGNAL LIGHTS:PEDESTRIAN CIRCULAR GREEN (I)'
#  'FAIL TO PROVE FIN RESPONSIBILITY:PEACE OFCR REQUEST (I)'
#  'LANE USAGE:PASS ON RIGHT:OPPOSITE DIRECTION (I)'
#  'PEDESTRIAN WALK ON LEFT EDGE OF ROAD (I)'
#  'BICYCLIST SHALL OBEY SIGNAL AND YIELD TO LAWFUL TRAFFIC (I)'
#  'BLOCKING INTERSECTION (I)'
#  'FAIL TO STOP AT LIMIT LINE AT RR CROSSING (I)'
#  'OVERTAKEN VEHICLE SAFELY MOVE TO THE RIGHT (I)'
#  'DRIVER SHALL OBEY DIRECTIONS OF TRAFFIC DEVICE (I)'
#  'RIGHT-OF-WAY: TO TURNING VEHICLES THAT HAVE YIELDED (I)'
#  'PEDESTRIAN WALK ON RIGHT EDGE OF ROAD (I)'
#  'TIRE NON-CONFORMANCE W/REGULATIONS (I)'
#  'RED REFLECTOR ON REAR OF BIKE REQUIRED (I)'
#  'BICYCLE HEADLIGHT/REFLECTOR VIOL (I)' 'RECKLESS DRVG:PARK LOT (M)'
#  'OFF HWY VEH:UNSAFE SPEED (BASIC SPEED LAW) (I)'
#  'LANE CONTROL SIGNAL:STEADY RED (I)' 'LANE USAGE:DRVG LEFT OF CENTER (I)'
#  'CROSS A TRAFFIC CONTROL CONE PATTERN/ELECTRONIC BEACON'
#  'FAILURE TO OBEY TRAFFIC SIGN (I)'
#  'PEDESTRIAN:CROSS IN CROSSWALK:PROHIB SIGN (I)'
#  'OPERATE MOTOR VEHICLE W/0.01% OR MORE BAC WHILE ON PROBATION FOR DUI (I)'
#  'TRESPASS WITH VEHICLE ETC:PUBLIC GROUNDS (I)'
#  'TOWED VEH:SAFETY CHAIN REQUIRED (I)'
#  'OPERATE VEH IN UNSAFE CONDITION; NOT EQUIPPED AS REQD; NOT SAFELY LOADED (I)'
#  'EXCEED 55 MPH STATUTORY SPEED:2-LANE ROADS (I)'
#  'LANE USAGE:SOLID/BROKEN DOUBLE LINE VIOL (I)'
#  'DUI ALCOHOL/DRUGS:CAUSING BODILY INJURY (F)'
#  'ENTERING RAILROAD OR RAIL TRANSIT CROSSING (I)'
#  'MANDATORY SEAT BELTS - PRIVATE VEHICLE PASSENGER AND DRIVER (I)'
#  'LANE USAGE:BICYCLIST FAILURE TO RIDE IN BIKE LANE (I)'
#  'RECKLESS DRIVING W/INJURY (M)'
#  'FAIL TO SIGNAL AT LEAST 100 FEET BEFORE TURN (I)'
#  'FAILURE TO PROVIDE INFO:INJ ACCIDENT (M)'
#  'BICYCLE OPERATORS SHALL OBEY VEHICLE LAWS (I)'
#  'ALLOWING UNLAWFUL RIDING IN VEH (I)' 'GIVE FALSE INFO TO PEACE OFCR'
#  'WHEN TURN SIGNAL LAMPS INOP:USE ARM SIGNALS (I)'
#  'CARRY PERS:BACK:TRUCK (I)'
#  'ILLEGAL MOVEMENT OF A STOPPED AND/OR PARKED VEHICLE (I)'
#  'TURNS:ILLEGAL U-TURN OBSTRUCTED VIEW (I)'
#  'RIDING BICYCLE UNDER INFLUENCE OF ALCOHOL AND/OR DRUGS(IBR 90E)'
#  'UNLAWFUL RIDING IN VEH (I)'
#  'CARRY ARTCL:PREV AT LEAST ONE HAND ON BICYCLE HANDLEBARS (I)'
#  'PARKING BICYCLE ON SIDEWALK/PEDESTRIAN PATH (I)'
#  'PARKING/STOP/ETC VEH VIOL:SPEC CIRC (I)'
#  'DRIVE VEH TOWING M/C. BIKE. ETC. W / PASSENGER (I)'
#  "LOAD OBSTRUCTING DRIVER'S VIEW (I)"
#  'FAIL TO PROVIDE ID/VEH DATA/FINANCIAL RESPONSIBILITY:ACCIDENT (I)'
#  'OPERATE MOTOR SCOOTER WITHOUT BRAKE (I)'
#  'DUI DRUG:CAUSING BODILY INJURY (M)'
#  'TRAFFIC CONTROL SIGNAL:FAILURE TO OBEY (I)' 'UNSAFE SPEED ON BRIDGE (I)'
#  'ILLEGAL SPEED EXHIBITION (M)'
#  'VEHICLE ON ROADWAY - REPORTED STOLEN OR EMBEZZLED (I)'
#  'DUI .08 ALC:CAUSING BODILY INJ (F)'
#  'FAIL TO PROVE FIN RESPONS:PEACE OFCR REQ AT COLLISION (I)'
#  'DRIVE WITHOUT LIGHTS AT DARK (I)' 'OFF HWY VEH:LITTERING FROM VEH (M)'
#  'RIGHT-OF-WAY:FAILED TO YIELD TO BLIND PEDESTRIAN (M)'
#  'NO BICYCLE LIGHT (I)' 'HITCH/ETC MOUNT VIOL (I)'
#  'UNLAWFUL STOP/PARK ON HIGHWAY IN UNINCORPORATED AREA (I)'
#  'HIT AND RUN VEHICLE (I)' 'OPERATE/PARK LOW SPEED VEHICLE (I)'
#  'TURNS:WRONG LANE U-TURN VIOL (I)'
#  'MINOR UNDER 21YR DRIVE W/BAC 0.05 (I)'
#  'VEHICLE PARKED ON ROADWAY - DRIVER INCAPACITATED (I)'
#  'NO PROOF OF INSURANCE PASSENGER VEH FOR HIRE (I)'
#  'SIGNAL LIGHTS:FLASHING YELLOW (I)'
#  'DUI ALC/0.04 PERCENT WHILE DRVG COMMERCIAL VEH (M)'
#  'ENTERING OR EXITING EXCLUSIVE OR PREFERENTIAL USE LANES (I)'
#  'SLOW SPEED - IMPEDING TRAFFIC (I)'
#  'FOLLOWING EMERGENCY VEH WITH 300 FT (I)'
#  'DRIVER CITED FOR UNLICENSED/SUSPENDED/REVOKED (I)'
#  'LANE USAGE:SPECIFIC VEH:USE WRONG PASS LANE (I)' 'BUS ZONE (I)'
#  'FAILURE TO MERGE INTO BICYCLE LANE BEFORE MAKING RIGHT TURN (I)'
#  'MOTORIZED SCOOTER - DISMOUNT FOR LEFT TURN (I)'
#  'RECKLESS DRIVING:SPECIFIED INJURIES (F)'
#  'MUST BE ABLE TO REACH AND OPERATE ALL CONTROLS (I)'
#  'EVADING PEACE OFCR:CAUSING SER INJ OR DEATH'
#  'SPEED CONTEST/RECKLESS DRIVIING (I)' 'DRIVER ARRESTED (I)'
#  'BICYCLIST OR PASSENGER RIDING ON NON-PERM SEAT OR NOT SEATED'
#  'POSTING OF HANDBILLS ON PARK/BEACH' "WALK, WAIT, OR DON'T WALK"
#  'FAIL OR REFUSE TO COMPLY W/ LAWFUL ORDER, SIGNAL, PEACE OFFICER'
#  'IMPROPERLY ATTACHED DRAWBAR OR OTHER CONNECTION'
#  'VEHICLE ON HWY STOLEN/EMBEZZLED'
#  'BICYCLIST,PERMITTING PASSENGER ON NON-PERM SEAT OR NOT SEATED'
#  'STOP REQUIREMENTS STATE STOP LINE LOCAL ORDINANCES'
#  'IMPOUND VEHICLE USED IN CRIME (CONTAINS EVIDENCE) (I)'
#  'MOTORIZED SCOOTER SHALL SAFELY LEAVE BIKE LANE (I)'
#  'MAY NOT IMPEDE OR BLOCK MOVEMENT OF BICYCLIST ON BIKEWAY, PATH OR TRAIL (I)'
#  'OFF HWY VEH:RECKLESS DRVG (M)' 'MOTORCYCLE SEAT VIOL (I)'
#  'VEH EXCEED FRAME HEIGHTS (M)']

# %%
#graph violation section

#plt.figure(figsize(15,8))

ax = sns.histplot(data = traffic_collisions_details_edited, x = 'violation_section', stat='probability')
ax.tick_params(axis='x', rotation=90)

# %%
#groupby and only get top 10 violation sections 

n_violation_section = traffic_collisions_details_edited.groupby('violation_section')['report_id'].nunique()
n_violation_section
# Out:
# violation_section
# 10851              2
# 10851(A)          12
# 11350(A)           2
# 12500              1
# 12500(A)         187
#                ...
# GANGS              1
# MISC              10
# MISC-HAZ       14086
# MISC-NONHAZ        1
# UNKNOWN           27
# Name: report_id, Length: 299, dtype: int64

# %%
df_n_violation = pd.DataFrame({'section':n_violation_section.index,'unique_counts':n_violation_section.values})

# %%
df_n_violation = df_n_violation.sort_values(by='unique_counts', ascending=False)

# %%
df_n_violation
# Out:
#       section  unique_counts
# 163     22107          16939
# 296  MISC-HAZ          14086
# 172     22350           8439
# 162     22106           4579
# 59     21453A           3568
# ..        ...            ...
# 53      21253              1
# 192    22502A              1
# 238    23152D              1
# 237    23152C              1
# 187    22500E              1
#
# [299 rows x 2 columns]

# %%
#add percentage column

df_n_violation['percentage'] = df_n_violation.unique_counts/df_n_violation.unique_counts.sum()
df_n_violation
# Out:
#       section  unique_counts  percentage
# 163     22107          16939    0.249228
# 296  MISC-HAZ          14086    0.207251
# 172     22350           8439    0.124165
# 162     22106           4579    0.067372
# 59     21453A           3568    0.052497
# ..        ...            ...         ...
# 53      21253              1    0.000015
# 192    22502A              1    0.000015
# 238    23152D              1    0.000015
# 237    23152C              1    0.000015
# 187    22500E              1    0.000015
#
# [299 rows x 3 columns]

# %%
#subset to get top 10

top_10_violation = df_n_violation.head(10)
top_10_violation
# Out:
#       section  unique_counts  percentage
# 163     22107          16939    0.249228
# 296  MISC-HAZ          14086    0.207251
# 172     22350           8439    0.124165
# 162     22106           4579    0.067372
# 59     21453A           3568    0.052497
# 102     21703           2395    0.035238
# 17   20002(A)           1790    0.026337
# 130    21801A           1683    0.024762
# 235    23152A           1492    0.021952
# 136     21804           1279    0.018818

# %%
ax = sns.barplot(data = top_10_violation, x = 'section', y = 'percentage')
ax.tick_params(axis='x', rotation=90)

# %%
traffic_collisions_details_edited.head()
# Out:
#   report_id           date_time              person_role person_injury_lvl  \
# 0    600096 2015-01-01 15:19:00                   DRIVER               NaN
# 1    600096 2015-01-01 15:19:00  PARKED VEHICLE OCCUPANT               NaN
# 2    600068 2015-01-02 13:04:00                   DRIVER           VISABLE
# 3    600051 2015-01-02 20:15:00  PARKED VEHICLE OCCUPANT               NaN
# 4    600441 2015-01-13 13:59:00                BICYCLIST              PAIN
#
#   person_veh_type    veh_type  veh_make             veh_model police_beat  \
# 0             NaN         NaN      FORD                   NaN         112
# 1             NaN         NaN      FORD               MUSTANG         112
# 2             NaN  MOTORCYCLE  KAWASAKI                   NaN         437
# 3             NaN         NaN    TOYOTA  MATRIX (SPORT WAGON)         833
# 4             NaN     BICYCLE       NaN                   NaN         611
#
#    address_no_primary address_pd_primary address_road_primary  \
# 0                3600                NaN           MT EVEREST
# 1                3600                NaN           MT EVEREST
# 2                2800                  S              WOODMAN
# 3                3800                NaN                MENLO
# 4                3500                NaN               MIDWAY
#
#   address_sfx_primary address_pd_intersecting address_name_intersecting  \
# 0           BOULEVARD                     NaN                       NaN
# 1           BOULEVARD                     NaN                       NaN
# 2              STREET                     NaN                       NaN
# 3              AVENUE                     NaN                       NaN
# 4               DRIVE                     NaN                       NaN
#
#   address_sfx_intersecting violation_section violation_type  \
# 0                      NaN             22107             VC
# 1                      NaN             22107             VC
# 2                      NaN            21801A             VC
# 3                      NaN             22107             VC
# 4                      NaN             82.22             MC
#
#                                       charge_desc  injured  killed  \
# 0          TURNING MOVEMENTS AND REQUIRED SIGNALS        0       0
# 1          TURNING MOVEMENTS AND REQUIRED SIGNALS        0       0
# 2            LEFT TURN YIELD UNTIL SAFE OR U-TURN        1       0
# 3          TURNING MOVEMENTS AND REQUIRED SIGNALS        0       0
# 4  STOP UPON EMERGING FROM ALLEY/PRIVATE DRIVEWAY        1       0
#
#    hit_run_lvl
# 0          NaN
# 1          NaN
# 2  MISDEMEANOR
# 3  MISDEMEANOR
# 4          NaN

# %% [markdown]
# Now lets see which vehicle type is most prominent- including make and model

# %%
#lets look at vehicle details

n_vehtype = traffic_collisions_details_edited.groupby('veh_type')['report_id'].count()
n_vehtype
# Out:
# veh_type
# AIRCRAFT                              34
# AIRCRAFT                               1
# ALL TERRAIN VEHICLE                   10
# ALL TERRAIN VEHICLE                   17
# AUTOMOBILE                         40616
# AUTOMOBILE                           692
# BICYCLE                             1970
# BICYCLE                              144
# FARM EQUIPMENT                       845
# LIGHT DUTY TRUCK                    5785
# MOTORCYCLE                          2602
# MOTORCYCLE                           159
# TRAILER                              396
# TRAILER                               26
# TRUCK                               1282
# TRUCK                                 55
# UNLISTED CONSTRUCTION EQUIPMENT       58
# Name: report_id, dtype: int64

# %%
df_n_vehtype = pd.DataFrame({'veh_type':n_vehtype.index,'counts':n_vehtype.values})
df_n_vehtype
# Out:
#                            veh_type  counts
# 0                          AIRCRAFT      34
# 1              AIRCRAFT                   1
# 2               ALL TERRAIN VEHICLE      10
# 3              ALL TERRAIN VEHICLE       17
# 4                        AUTOMOBILE   40616
# 5              AUTOMOBILE               692
# 6                           BICYCLE    1970
# 7              BICYCLE                  144
# 8                    FARM EQUIPMENT     845
# 9                  LIGHT DUTY TRUCK    5785
# 10                       MOTORCYCLE    2602
# 11             MOTORCYCLE               159
# 12                          TRAILER     396
# 13             TRAILER                   26
# 14                            TRUCK    1282
# 15             TRUCK                     55
# 16  UNLISTED CONSTRUCTION EQUIPMENT      58

# %%
#there are repeats, lets combine the repeats 

#create column for each type and then rotate df
df_n_vehtype['AIRCRAFT'] = 34 + 1
df_n_vehtype['All TERRAIN VEHICLE'] = 10+17
df_n_vehtype['AUTOMOBILE'] = 40361 + 697
df_n_vehtype['BICYCLE'] = 1971+146
df_n_vehtype['FARM EQUIPMENT'] = 841
df_n_vehtype['LIGHT DUTY TRUCK'] =5769
df_n_vehtype['MOTORCYCLE'] = 2593+162
df_n_vehtype['TRAILER'] = 394+26
df_n_vehtype['TRUCK'] =1284+55
df_n_vehtype['UNLISTED CONSTRUCTION EQUIPMENT'] = 58
df_sum_vehtype = pd.DataFrame(df_n_vehtype.iloc[0,2:]).reset_index()
df_sum_vehtype.rename(columns = {'index':'vehicle_type',0:'count'}, inplace=True)
df_sum_vehtype
# Out:
#                       vehicle_type  count
# 0                         AIRCRAFT     35
# 1              All TERRAIN VEHICLE     27
# 2                       AUTOMOBILE  41058
# 3                          BICYCLE   2117
# 4                   FARM EQUIPMENT    841
# 5                 LIGHT DUTY TRUCK   5769
# 6                       MOTORCYCLE   2755
# 7                          TRAILER    420
# 8                            TRUCK   1339
# 9  UNLISTED CONSTRUCTION EQUIPMENT     58

# %%
df_sum_vehtype['percentage'] = df_sum_vehtype['count']/df_sum_vehtype['count'].sum()
df_sum_vehtype
# Out:
#                       vehicle_type  count percentage
# 0                         AIRCRAFT     35   0.000643
# 1              All TERRAIN VEHICLE     27   0.000496
# 2                       AUTOMOBILE  41058   0.754479
# 3                          BICYCLE   2117   0.038902
# 4                   FARM EQUIPMENT    841   0.015454
# 5                 LIGHT DUTY TRUCK   5769   0.106011
# 6                       MOTORCYCLE   2755   0.050626
# 7                          TRAILER    420   0.007718
# 8                            TRUCK   1339   0.024605
# 9  UNLISTED CONSTRUCTION EQUIPMENT     58   0.001066

# %%
ax = sns.barplot(data = df_sum_vehtype, x = 'vehicle_type', y = 'percentage')
ax.tick_params(axis='x', rotation=90)

# %%
#now for vehicle make 

n_vehmake = traffic_collisions_details_edited.groupby('veh_make')['report_id'].count()
n_vehmake
# Out:
# veh_make
# 1UP                     1
# 6000                    1
# 6KU                     3
# A & M BOAT TRAILER      1
# A1 CYCLES               1
#                        ..
# ZHONGNENG MOTORCYCLE    1
# ZIEMAN                  8
# ZIPPER                  1
# ZONGSHEN MTRCYCLE CO    1
# _                       1
# Name: report_id, Length: 703, dtype: int64

# %%
n_vehmake_df = pd.DataFrame({'make':n_vehmake.index,'counts':n_vehmake.values})
n_vehmake_df
# Out:
#                      make  counts
# 0                     1UP       1
# 1                    6000       1
# 2                     6KU       3
# 3      A & M BOAT TRAILER       1
# 4               A1 CYCLES       1
# ..                    ...     ...
# 698  ZHONGNENG MOTORCYCLE       1
# 699                ZIEMAN       8
# 700                ZIPPER       1
# 701  ZONGSHEN MTRCYCLE CO       1
# 702                     _       1
#
# [703 rows x 2 columns]

# %%
#sort by descending 

n_vehmake_df = n_vehmake_df.sort_values(by='counts', ascending=False)
n_vehmake_df
# Out:
#                                        make  counts
# 621                                  TOYOTA   18823
# 209                                    FORD   12725
# 273                                   HONDA   12630
# 431                                  NISSAN    8575
# 118                               CHEVROLET    6792
# ..                                      ...     ...
# 282                              HYPER BIKE       1
# 281                          HYPER BICYCLES       1
# 280                                   HYPER       1
# 279  HYOSUNG MOTORS & MACHINERY SOUTH KOREA       1
# 702                                       _       1
#
# [703 rows x 2 columns]

# %%
n_vehmake_df['percentage'] = n_vehmake_df.counts/n_vehmake_df.counts.sum()
n_vehmake_df
# Out:
#                                        make  counts  percentage
# 621                                  TOYOTA   18823    0.176903
# 209                                    FORD   12725    0.119592
# 273                                   HONDA   12630    0.118700
# 431                                  NISSAN    8575    0.080590
# 118                               CHEVROLET    6792    0.063833
# ..                                      ...     ...         ...
# 282                              HYPER BIKE       1    0.000009
# 281                          HYPER BICYCLES       1    0.000009
# 280                                   HYPER       1    0.000009
# 279  HYOSUNG MOTORS & MACHINERY SOUTH KOREA       1    0.000009
# 702                                       _       1    0.000009
#
# [703 rows x 3 columns]

# %%
#subset get top 10

top_10makes = n_vehmake_df.head(10)
top_10makes
# Out:
#            make  counts  percentage
# 621      TOYOTA   18823    0.176903
# 209        FORD   12725    0.119592
# 273       HONDA   12630    0.118700
# 431      NISSAN    8575    0.080590
# 118   CHEVROLET    6792    0.063833
# 286     HYUNDAI    3690    0.034679
# 161       DODGE    3412    0.032067
# 46       B.M.W.    3244    0.030488
# 664  VOLKSWAGEN    2850    0.026785
# 317        JEEP    2683    0.025215

# %%
ax = sns.barplot(data = top_10makes, x = 'make', y = 'percentage')
ax.tick_params(axis='x', rotation=90)

# %%
#vehicle model 

n_vehmodel = traffic_collisions_details_edited.groupby('veh_model')['report_id'].count()
n_vehmodel
# Out:
# veh_model
# 100           1
# 1000          1
# 1200          2
# 122 SERIES    2
# 128I          1
#              ..
# crosstrek     3
# elantra       1
# f150          1
# fiesta        3
# spark         1
# Name: report_id, Length: 1016, dtype: int64

# %%
n_vehmodel = pd.DataFrame({'model':n_vehmodel.index,'counts':n_vehmodel.values})
n_vehmodel
# Out:
#            model  counts
# 0            100       1
# 1           1000       1
# 2           1200       2
# 3     122 SERIES       2
# 4           128I       1
# ...          ...     ...
# 1011   crosstrek       3
# 1012     elantra       1
# 1013        f150       1
# 1014      fiesta       3
# 1015       spark       1
#
# [1016 rows x 2 columns]

# %%
#sort by descending 

n_vehmodel = n_vehmodel.sort_values(by='counts', ascending=False)
n_vehmodel
# Out:
#                 model  counts
# 199             CAMRY    3647
# 121            ACCORD    3450
# 271           COROLLA    3369
# 684             PRIUS    2573
# 232   CIVIC (AND CRX)    2562
# ...               ...     ...
# 536            KLX650       1
# 535            KLX300       1
# 528              JETT       1
# 525           Impreza       1
# 1015            spark       1
#
# [1016 rows x 2 columns]

# %%
n_vehmodel['percentage'] = n_vehmodel.counts/n_vehmodel.counts.sum()
n_vehmodel
# Out:
#                 model  counts  percentage
# 199             CAMRY    3647    0.044202
# 121            ACCORD    3450    0.041815
# 271           COROLLA    3369    0.040833
# 684             PRIUS    2573    0.031185
# 232   CIVIC (AND CRX)    2562    0.031052
# ...               ...     ...         ...
# 536            KLX650       1    0.000012
# 535            KLX300       1    0.000012
# 528              JETT       1    0.000012
# 525           Impreza       1    0.000012
# 1015            spark       1    0.000012
#
# [1016 rows x 3 columns]

# %%
top_10models = n_vehmodel.head(10)
ax = sns.barplot(data = top_10models, x = 'model', y = 'percentage')
ax.tick_params(axis='x', rotation=90)

# %% [markdown]
# Now lets see which police beat is most prominent- police beat can tell us about general location

# %%
#police beat 

n_beat = traffic_collisions_details_edited.groupby('police_beat')['report_id'].nunique()
n_beat
# Out:
# police_beat
# 3        1
# 20       2
# 21       5
# 24       1
# 26       1
#       ...
# 934    295
# 935     71
# 936     42
# 937     69
# 999     40
# Name: report_id, Length: 284, dtype: int64

# %%
n_beat = pd.DataFrame({'beat':n_beat.index,'counts':n_beat.values})
n_beat
# Out:
#     beat  counts
# 0      3       1
# 1     20       2
# 2     21       5
# 3     24       1
# 4     26       1
# ..   ...     ...
# 279  934     295
# 280  935      71
# 281  936      42
# 282  937      69
# 283  999      40
#
# [284 rows x 2 columns]

# %%
n_beat = n_beat.sort_values(by='counts', ascending=False)
n_beat
# Out:
#     beat  counts
# 14   122    2483
# 112  813    1419
# 25   242    1365
# 31   313    1306
# 16   124    1248
# ..   ...     ...
# 184  404       1
# 185  419       1
# 204  500       1
# 205  503       1
# 0      3       1
#
# [284 rows x 2 columns]

# %%
n_beat['percentage'] = n_beat.counts/n_beat.counts.sum()
n_beat
# Out:
#     beat  counts  percentage
# 14   122    2483    0.036532
# 112  813    1419    0.020878
# 25   242    1365    0.020083
# 31   313    1306    0.019215
# 16   124    1248    0.018362
# ..   ...     ...         ...
# 184  404       1    0.000015
# 185  419       1    0.000015
# 204  500       1    0.000015
# 205  503       1    0.000015
# 0      3       1    0.000015
#
# [284 rows x 3 columns]

# %%
top_10beats = n_beat.head(10)
ax = sns.barplot(data = top_10beats, x = 'beat', y = 'percentage')
ax.tick_params(axis='x', rotation=90)

# %% [markdown]
# So it seems that there isnt a really prominent police beat present

# %% [markdown]
# Now check time aspects- does a year have more collisions, does a month have more collisions, hour?

# %%
traffic_collisions_details_edited.head()
# Out:
#   report_id           date_time              person_role person_injury_lvl  \
# 0    600096 2015-01-01 15:19:00                   DRIVER               NaN
# 1    600096 2015-01-01 15:19:00  PARKED VEHICLE OCCUPANT               NaN
# 2    600068 2015-01-02 13:04:00                   DRIVER           VISABLE
# 3    600051 2015-01-02 20:15:00  PARKED VEHICLE OCCUPANT               NaN
# 4    600441 2015-01-13 13:59:00                BICYCLIST              PAIN
#
#   person_veh_type    veh_type  veh_make             veh_model police_beat  \
# 0             NaN         NaN      FORD                   NaN         112
# 1             NaN         NaN      FORD               MUSTANG         112
# 2             NaN  MOTORCYCLE  KAWASAKI                   NaN         437
# 3             NaN         NaN    TOYOTA  MATRIX (SPORT WAGON)         833
# 4             NaN     BICYCLE       NaN                   NaN         611
#
#    address_no_primary address_pd_primary address_road_primary  \
# 0                3600                NaN           MT EVEREST
# 1                3600                NaN           MT EVEREST
# 2                2800                  S              WOODMAN
# 3                3800                NaN                MENLO
# 4                3500                NaN               MIDWAY
#
#   address_sfx_primary address_pd_intersecting address_name_intersecting  \
# 0           BOULEVARD                     NaN                       NaN
# 1           BOULEVARD                     NaN                       NaN
# 2              STREET                     NaN                       NaN
# 3              AVENUE                     NaN                       NaN
# 4               DRIVE                     NaN                       NaN
#
#   address_sfx_intersecting violation_section violation_type  \
# 0                      NaN             22107             VC
# 1                      NaN             22107             VC
# 2                      NaN            21801A             VC
# 3                      NaN             22107             VC
# 4                      NaN             82.22             MC
#
#                                       charge_desc  injured  killed  \
# 0          TURNING MOVEMENTS AND REQUIRED SIGNALS        0       0
# 1          TURNING MOVEMENTS AND REQUIRED SIGNALS        0       0
# 2            LEFT TURN YIELD UNTIL SAFE OR U-TURN        1       0
# 3          TURNING MOVEMENTS AND REQUIRED SIGNALS        0       0
# 4  STOP UPON EMERGING FROM ALLEY/PRIVATE DRIVEWAY        1       0
#
#    hit_run_lvl
# 0          NaN
# 1          NaN
# 2  MISDEMEANOR
# 3  MISDEMEANOR
# 4          NaN

# %%
n_date = traffic_collisions_details_edited.groupby([traffic_collisions_details_edited['date_time'].dt.date])['report_id'].nunique()
n_date
# Out:
# date_time
# 2015-01-01     1
# 2015-01-02     2
# 2015-01-13     1
# 2015-01-14     1
# 2015-02-19     1
#               ..
# 2022-05-06    18
# 2022-05-07    21
# 2022-05-08    12
# 2022-05-09     7
# 2022-05-10     2
# Name: report_id, Length: 2603, dtype: int64

# %%
n_date = pd.DataFrame({'date':n_date.index,'counts':n_date.values})
n_date
# Out:
#             date  counts
# 0     2015-01-01       1
# 1     2015-01-02       2
# 2     2015-01-13       1
# 3     2015-01-14       1
# 4     2015-02-19       1
# ...          ...     ...
# 2598  2022-05-06      18
# 2599  2022-05-07      21
# 2600  2022-05-08      12
# 2601  2022-05-09       7
# 2602  2022-05-10       2
#
# [2603 rows x 2 columns]

# %%
n_date.describe()
# Out:
#             counts
# count  2603.000000
# mean     26.110642
# std       7.207428
# min       1.000000
# 25%      22.000000
# 50%      26.000000
# 75%      31.000000
# max      53.000000

# %%
#lets see top ten dates
n_date_top = n_date.sort_values(by='counts', ascending=False)
n_date_top
# Out:
#             date  counts
# 1164  2018-06-02      53
# 117   2015-07-21      49
# 1331  2018-11-16      49
# 981   2017-12-01      47
# 267   2015-12-18      47
# ...          ...     ...
# 13    2015-03-27       1
# 22    2015-04-16       1
# 15    2015-04-02       1
# 16    2015-04-09       1
# 0     2015-01-01       1
#
# [2603 rows x 2 columns]

# %%
n_date_top_10= n_date_top.head(10)
ax = sns.barplot(data = n_date_top_10, x = 'date', y = 'counts')
ax.tick_params(axis='x', rotation=90)

# %% [markdown]
# Seems like all of these are in later years. I will make sure that earlier years also have a high number of accidents to see if perhaps a change in reporting caused this difference vs. a true statistical difference

# %%
#let me check year alone

n_year = traffic_collisions_details_edited.groupby([traffic_collisions_details_edited['date_time'].dt.year])['report_id'].nunique()
n_year
# Out:
# date_time
# 2015     7327
# 2016    10563
# 2017    10238
# 2018     9905
# 2019    10177
# 2020     8062
# 2021     9005
# 2022     2689
# Name: report_id, dtype: int64

# %%
n_year = pd.DataFrame({'year':n_year.index,'counts':n_year.values})
n_year
# Out:
#    year  counts
# 0  2015    7327
# 1  2016   10563
# 2  2017   10238
# 3  2018    9905
# 4  2019   10177
# 5  2020    8062
# 6  2021    9005
# 7  2022    2689

# %%
ax = sns.barplot(data = n_year, x = 'year', y = 'counts')
ax.tick_params(axis='x', rotation=90)

# %%
#let me check month
#let me check year alone

n_month = traffic_collisions_details_edited.groupby([traffic_collisions_details_edited['date_time'].dt.month])['report_id'].nunique()
n_month
# Out:
# date_time
# 1     5387
# 2     5154
# 3     5597
# 4     5088
# 5     5633
# 6     5745
# 7     6061
# 8     6020
# 9     6003
# 10    6127
# 11    5487
# 12    5664
# Name: report_id, dtype: int64

# %%
n_month = pd.DataFrame({'month':n_month.index,'counts':n_month.values})
n_month
# Out:
#     month  counts
# 0       1    5387
# 1       2    5154
# 2       3    5597
# 3       4    5088
# 4       5    5633
# 5       6    5745
# 6       7    6061
# 7       8    6020
# 8       9    6003
# 9      10    6127
# 10     11    5487
# 11     12    5664

# %%
ax = sns.barplot(data = n_month, x = 'month', y = 'counts')
ax.tick_params(axis='x', rotation=90)

# %% [markdown]
# Collisions do not seem to differ much between all the months. I'd assume that later months would have more collisions because of holidays and bad weather.

# %%
#now lets check day of the month-- maybe more accidents in the start of the month 
n_day = traffic_collisions_details_edited.groupby([traffic_collisions_details_edited['date_time'].dt.day])['report_id'].nunique()
n_day
# Out:
# date_time
# 1     2288
# 2     2306
# 3     2207
# 4     2283
# 5     2335
# 6     2217
# 7     2268
# 8     2214
# 9     2312
# 10    2163
# 11    2278
# 12    2262
# 13    2317
# 14    2280
# 15    2242
# 16    2277
# 17    2261
# 18    2288
# 19    2221
# 20    2244
# 21    2237
# 22    2237
# 23    2186
# 24    2159
# 25    2064
# 26    2111
# 27    2186
# 28    2172
# 29    2061
# 30    2035
# 31    1255
# Name: report_id, dtype: int64

# %%
n_day = pd.DataFrame({'day':n_day.index,'counts':n_day.values})
n_day
# Out:
#     day  counts
# 0     1    2288
# 1     2    2306
# 2     3    2207
# 3     4    2283
# 4     5    2335
# 5     6    2217
# 6     7    2268
# 7     8    2214
# 8     9    2312
# 9    10    2163
# 10   11    2278
# 11   12    2262
# 12   13    2317
# 13   14    2280
# 14   15    2242
# 15   16    2277
# 16   17    2261
# 17   18    2288
# 18   19    2221
# 19   20    2244
# 20   21    2237
# 21   22    2237
# 22   23    2186
# 23   24    2159
# 24   25    2064
# 25   26    2111
# 26   27    2186
# 27   28    2172
# 28   29    2061
# 29   30    2035
# 30   31    1255

# %%
ax = sns.barplot(data = n_day, x = 'day', y = 'counts')
ax.tick_params(axis='x', rotation=90)

# %% [markdown]
# Again there is an even distribution among all the days. Dip for the 31st can be attributed to that not all months have 31 days.
